# %% [markdown]
# # Librerias

# %%
! pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages (24.0.0)

# %%
import pandas as pd

# %% [markdown]
# # Carga de la bbdd

# %%
ruta = r"C:\\Users\\ADMIN\\Desktop\\Barcelona Activa\\Bootcamp\\Simulador empresarial\\ProjecteData\\Equip_27\\Data\\df_limpiado_260420.parquet"
df=pd.read_parquet(ruta)
df = df.reset_index()
df
# Out:
#           id   age             job  marital  education default  balance  \
# 0          1  59.0  administration  married  secondary      no     2343
# 1          2  56.0  administration  married  secondary      no       45
# 2          3  41.0      technician  married  secondary      no     1270
# 3          4  55.0        services  married  secondary      no     2476
# 4          5  54.0  administration  married   tertiary      no      184
# ...      ...   ...             ...      ...        ...     ...      ...
# 10637  10638  33.0      technician  married  secondary      no      218
# 10638  10639  42.0      management   single   tertiary      no     1146
# 10639  10640  31.0      unemployed   single    unknown      no      167
# 10640  10641  30.0     blue-collar   single  secondary     yes      447
# 10641  10642  40.0      management   single  secondary      no    10378
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 0         yes   no    unknown    5   may    1042.0         1    NaN         0
# 1          no   no    unknown    5   may    1467.0         1    NaN         0
# 2         yes   no    unknown    5   may    1389.0         1    NaN         0
# 3         yes   no    unknown    5   may     579.0         1    NaN         0
# 4          no   no    unknown    5   may     673.0         2    NaN         0
# ...       ...  ...        ...  ...   ...       ...       ...    ...       ...
# 10637     yes  yes  telephone    2   mar     169.0         4    NaN         0
# 10638     yes   no    unknown   15   may      98.0         2    NaN         0
# 10639      no   no   cellular   20   nov     316.0         1    NaN         0
# 10640      no   no   cellular   19   nov     426.0         2  189.0         6
# 10641     yes   no   cellular   17   nov     523.0         3    NaN         0
#
#                   poutcome deposit  contactado_campania_previa
# 0      sin_campania_previa     yes                           0
# 1      sin_campania_previa     yes                           0
# 2      sin_campania_previa     yes                           0
# 3      sin_campania_previa     yes                           0
# 4      sin_campania_previa     yes                           0
# ...                    ...     ...                         ...
# 10637  sin_campania_previa      no                           0
# 10638  sin_campania_previa      no                           0
# 10639  sin_campania_previa      no                           0
# 10640              failure      no                           1
# 10641  sin_campania_previa      no                           0
#
# [10642 rows x 19 columns]

# %% [markdown]
# # KPI's:

# %% [markdown]
# ## 1. Porcentaje de conversión a depósito

# %%
# Número de clientes que suscribieron
num_suscriptores=df[df['deposit']==True].nunique().id
print("El número de clientes que suscribieron es: ",num_suscriptores)

#Número total de clientes contactados
clientes_contactados=df.nunique().id

print("El número total de clientes contactados es: ", clientes_contactados)

#Porcentaje de conversión a depósito (kpi1)
kpi1=num_suscriptores/clientes_contactados

print("KPI 1: El porcentaje de conversión a depósito es ",kpi1*100,"%")
# Out:
# El número de clientes que suscribieron es:  0
# El número total de clientes contactados es:  10642
# KPI 1: El porcentaje de conversión a depósito es  0.0 %

# %% [markdown]
# ## 2. Promedio de duración de llamadas de suscriptores

# %%
#Sumatoria de la duración de llamadas de suscriptores
duracion_total_llam=df[df['deposit']==True].duration.sum()
print("La duración total de las llamadas a suscriptores es:",duracion_total_llam)

#Número de clientes que suscribieron
clientes_suscritos=df[df['deposit']==True].nunique().id  

kpi2=duracion_total_llam/clientes_suscritos
print("KPI 2: La duración media de las llamadas a suscriptoreses: ",kpi2)
# Out:
# La duración total de las llamadas a suscriptores es: 0.0
# KPI 2: La duración media de las llamadas a suscriptoreses:  nan
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19556\2123879969.py:8: RuntimeWarning: invalid value encountered in scalar divide
#   kpi2=duracion_total_llam/clientes_suscritos

# %% [markdown]
# ## 3. Porcentaje de llamadas a teléfono o móvil

# %%
count_tlf = df[df['contact'] == 'telephone']['campaign'].sum()
count_mvl = df[df['contact'] == 'cellular']['campaign'].sum() 
count_llamadas = df['campaign'].sum()

porcentaje_tlf = (count_tlf / count_llamadas)*100
porcentaje_mvl = (count_mvl / count_llamadas)*100

kpi3_tlf = porcentaje_tlf
kpi3_mvl = porcentaje_mvl

print(f"El porcentaje de llamadas a teléfono es del {round(kpi3_tlf,2)}%.")
print(f"El porcentaje de llamadas a móvil es del {round(kpi3_mvl,2)}%.")
# Out:
# El porcentaje de llamadas a teléfono es del 8.03%.
# El porcentaje de llamadas a móvil es del 69.8%.

# %% [markdown]
# ## 4. Promedio de contactos previos de suscriptores

# %%
contactos_previos = df[df['deposit'] == 'yes']['previous'].sum()

promedio_contactos = (contactos_previos / num_suscriptores)

kpi4 = promedio_contactos

print(f"El promedio de contactos previos es de {round(kpi4,2)}.")
# Out:
# El promedio de contactos previos es de inf.
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19556\2269561751.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   promedio_contactos = (contactos_previos / num_suscriptores)

# %% [markdown]
# ## 5. Mes con mayor tasa de conversión

# %%
suscriptores_mes = df[df['deposit'] == 'yes'].groupby('month').count()['id']
contactados_mes = df.groupby('month').count()['id']
conversion_mes = suscriptores_mes / contactados_mes

max_mes = conversion_mes.idxmax()
max_conversion = (conversion_mes.max())*100

kpi5_mes = max_conversion
kpi5_tasa = max_conversion

print(f"El mes con mayor tasa de conversión es {kpi5_mes} con un {round(kpi5_tasa,2)}%.")
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19556\2348492276.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   suscriptores_mes = df[df['deposit'] == 'yes'].groupby('month').count()['id']
# El mes con mayor tasa de conversión es 91.74311926605505 con un 91.74%.
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19556\2348492276.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contactados_mes = df.groupby('month').count()['id']

# %% [markdown]
# # Conclusiones
