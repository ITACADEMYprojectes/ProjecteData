# %% [markdown]
# ## Librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carga datos clean

# %% [markdown]
# ## Análisis / visualizaciones

# %% [markdown]
# ## Resultados / archivos generados
