# %%
import pandas as pd

columns = ["availability_30", "availability_60", "availability_90", "availability_365"]

avg_availability = (
    df.groupby("city", dropna=False)[columns]
      .mean(numeric_only=True)
      .round(1)
      .sort_index()
)
avg_availability
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       1 import pandas as pd
#       3 columns = ["availability_30", "availability_60", "availability_90", "availability_365"]
#       5 avg_availability = (
# ----> 6     df.groupby("city", dropna=False)[columns]
#       7       .mean(numeric_only=True)
#       8       .round(1)
#       9       .sort_index()
#      10 )
#      11 avg_availability
#
# NameError: name 'df' is not defined
