# %% [markdown]
# ### Librerías

# %%
import mysql.connector
import pandas as pd

# %% [markdown]
# ### Carga de datos de la tabla en MySQL al fichero en formato CSV

# %%
config = {
  'user': 'Equipo27',
  'password': 'E1q2u3i4p5o27',
  'host': '212.227.90.6',
  'database': 'Equip_27',
  'port': 3306,
  'raise_on_warnings': True
}

nombre_table = 'BANK_marketing'

connection = mysql.connector.connect(** config)
cursor = connection.cursor()


cursor.execute("SHOW TABLES")
tables = cursor.fetchall()

dataframes = {}

for table in tables:
    table_name = table[0]
    query = f'SELECT * FROM {table_name}'
    cursor.execute(query)
    rows = cursor.fetchall()
    columns = [col[0] for col in cursor.description]
    dataframes[table_name] = pd.DataFrame(rows, columns=columns)

df_clientes = dataframes[nombre_table]

# %%
df_clientes.set_index('id', inplace=True)

# %%
df_clientes.shape
# Out:
# (11162, 17)

# %%
df_clientes.head(10)
# Out:
#      age         job   marital  education default  balance housing loan  \
# id
# 1   59.0      admin.   married  secondary      no     2343     yes   no
# 2   56.0      admin.   married  secondary      no       45      no   no
# 3   41.0  technician   married  secondary      no     1270     yes   no
# 4   55.0    services   married  secondary      no     2476     yes   no
# 5   54.0      admin.   married   tertiary      no      184      no   no
# 6   42.0  management    single   tertiary      no        0     yes  yes
# 7   56.0  management   married   tertiary      no      830     yes  yes
# 8   60.0     retired  divorced  secondary      no      545     yes   no
# 9   37.0  technician   married  secondary      no        1     yes   no
# 10  28.0    services    single  secondary      no     5090     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome deposit
# id
# 1   unknown    5   may      1042         1     -1         0  unknown     yes
# ...

# %%
#Se guarda directo en carpeta de Data:
df_clientes.to_csv("../../Data/df_original_260504.csv", index=False)
