# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# **Esta EDA funciona para descubrir patrones y problemas iniciales:**
# - Resúmenes estadísticos.
# - Visualizaciones iniciales para identificar tendencias o anomalías.
# - Correlaciones entre variables.

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **1. Cargar la base de datos**

# %%
ruta = os.path.join('..', 'Data', 'TouristAccommodationRaw19012026.csv')
df = pd.read_csv(ruta)

# %% [markdown]
# **2. Información general de la tabla**

# %%
# Un vistazo a la tabla con los primeros registros
df.head(5)
# Out:
#    apartment_id                                               name  \
# 0         11964                                 A ROOM WITH A VIEW
# 1         21853                               Bright and airy room
# 2         32347  Explore Cultural Sights from a Family-Friendly...
# 3         35379                  Double 02 CasanovaRooms Barcelona
# 4         35801                  Can Torras Farmhouse Studio Suite
#
#                                          description  host_id  \
# 0  Private bedroom in our attic apartment. Right ...    45553
# 1  We have a quiet and sunny room with a good vie...    83531
# 2  Open French doors and step onto a plant-filled...   139939
# 3  Room at a my apartment. Kitchen and 2 bathroom...   152232
# 4  Lay in bed & watch sunlight change the mood of...   153805
#
#                 neighbourhood_name neighbourhood_district        room_type  \
# 0                           Centro                    NaN     Private room
# 1                         C�rmenes                 Latina     Private room
# 2                      San Vicente          Casco Antiguo  Entire home/apt
# 3  l'Antiga Esquerra de l'Eixample               Eixample     Private room
# 4                            Quart                    NaN     Private room
#
#    accommodates  bathrooms  bedrooms  ...  review_scores_cleanliness  \
# 0             2        2.0       1.0  ...                      100.0
# 1             1        1.0       1.0  ...                       90.0
# 2             4        1.0       2.0  ...                      100.0
# 3             2        2.0       1.0  ...                       90.0
# 4             5        1.0       2.0  ...                      100.0
#
#   review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                 100.0                        100.0                   100.0
# 1                 100.0                        100.0                    80.0
# 2                 100.0                        100.0                   100.0
# 3                 100.0                        100.0                   100.0
# 4                 100.0                        100.0                   100.0
#
#    review_scores_value is_instant_bookable  reviews_per_month  country  \
# 0                100.0               FALSO               75.0    spain
# 1                 90.0               FALSO               52.0    spain
# 2                100.0           VERDADERO              142.0    spain
# 3                 90.0           VERDADERO              306.0    spain
# 4                100.0               FALSO               39.0    spain
#
#         city  insert_date
# 0     malaga   31/07/2018
# 1     madrid   10/01/2020
# 2    sevilla   29/07/2019
# 3  barcelona   10/01/2020
# 4     girona   19/02/2019
#
# [5 rows x 35 columns]

# %%
# Revisar información de las columnas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7001 entries, 0 to 7000
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   apartment_id                 7001 non-null   int64
#  1   name                         6998 non-null   object
#  2   description                  6972 non-null   object
#  3   host_id                      7001 non-null   int64
#  4   neighbourhood_name           7001 non-null   object
#  5   neighbourhood_district       4241 non-null   object
#  6   room_type                    7001 non-null   object
#  7   accommodates                 7001 non-null   int64
#  8   bathrooms                    6969 non-null   float64
#  9   bedrooms                     6972 non-null   float64
#  10  beds                         6998 non-null   float64
#  11  amenities_list               6984 non-null   object
#  12  price                        6870 non-null   float64
#  13  minimum_nights               7001 non-null   int64
#  14  maximum_nights               7001 non-null   int64
#  15  has_availability             6451 non-null   object
#  16  availability_30              7001 non-null   int64
#  17  availability_60              7001 non-null   int64
#  18  availability_90              7001 non-null   int64
#  19  availability_365             7001 non-null   int64
#  20  number_of_reviews            7001 non-null   int64
#  21  first_review_date            5747 non-null   object
#  22  last_review_date             5746 non-null   object
#  23  review_scores_rating         5674 non-null   float64
#  24  review_scores_accuracy       5665 non-null   float64
#  25  review_scores_cleanliness    5671 non-null   float64
#  26  review_scores_checkin        5660 non-null   float64
#  27  review_scores_communication  5669 non-null   float64
#  28  review_scores_location       5659 non-null   float64
#  29  review_scores_value          5659 non-null   float64
#  30  is_instant_bookable          7001 non-null   object
#  31  reviews_per_month            5747 non-null   float64
#  32  country                      7001 non-null   object
#  33  city                         7001 non-null   object
#  34  insert_date                  7001 non-null   object
# dtypes: float64(12), int64(10), object(13)
# memory usage: 1.9+ MB

# %% [markdown]
# **3. Descripción estadística**

# %%
# Resumen estadístico de las columnas numéricas
df.describe().transpose()
# Out:
#                               count          mean           std      min  \
# apartment_id                 7001.0  1.511978e+07  7.715578e+06  11964.0
# host_id                      7001.0  6.218673e+07  5.747094e+07  10704.0
# accommodates                 7001.0  4.351807e+00  2.620646e+00      1.0
# bathrooms                    6969.0  1.607117e+00  9.896339e-01      0.0
# bedrooms                     6972.0  1.968158e+00  1.300217e+00      0.0
# beds                         6998.0  3.013575e+00  2.330849e+00      0.0
# price                        6870.0  1.011098e+03  8.459754e+02     60.0
# minimum_nights               7001.0  4.424939e+00  1.066957e+01      1.0
# maximum_nights               7001.0  7.594676e+02  4.979648e+02      1.0
# availability_30              7001.0  1.227739e+01  1.151080e+01      0.0
# availability_60              7001.0  2.741994e+01  2.241343e+01      0.0
# availability_90              7001.0  4.430667e+01  3.301718e+01      0.0
# availability_365             7001.0  1.881294e+02  1.299563e+02      0.0
# number_of_reviews            7001.0  3.412541e+01  5.993561e+01      0.0
# review_scores_rating         5674.0  9.202326e+02  8.535395e+01    200.0
# review_scores_accuracy       5665.0  9.454369e+01  9.063156e+00     20.0
# review_scores_cleanliness    5671.0  9.319697e+01  9.702261e+00     20.0
# review_scores_checkin        5660.0  9.628799e+01  7.963854e+00     20.0
# review_scores_communication  5669.0  9.643500e+01  7.605426e+00     20.0
# review_scores_location       5659.0  9.531189e+01  7.295274e+00     20.0
# review_scores_value          5659.0  9.145962e+01  9.309337e+00     20.0
# reviews_per_month            5747.0  1.230412e+02  1.531618e+02      1.0
#
#                                     25%         50%          75%          max
# apartment_id                  8749646.0  16737061.0   21463214.0   27245117.0
# host_id                      10500150.0  42613804.0  106289587.0  336524176.0
# accommodates                        2.0         4.0          6.0         29.0
# bathrooms                           1.0         1.0          2.0         12.0
# bedrooms                            1.0         2.0          3.0         16.0
# beds                                1.0         2.0          4.0         30.0
# price                             450.0       750.0       1230.0       6071.0
# minimum_nights                      1.0         2.0          4.0        365.0
# maximum_nights                     70.0      1125.0       1125.0       1125.0
# availability_30                     0.0        10.0         24.0         30.0
# availability_60                     2.0        26.0         50.0         60.0
# availability_90                     9.0        46.0         76.0         90.0
# availability_365                   66.0       190.0        316.0        365.0
# number_of_reviews                   1.0         9.0         40.0        588.0
# review_scores_rating              890.0       940.0        980.0       1000.0
# review_scores_accuracy             90.0       100.0        100.0        100.0
# review_scores_cleanliness          90.0       100.0        100.0        100.0
# review_scores_checkin              90.0       100.0        100.0        100.0
# review_scores_communication        90.0       100.0        100.0        100.0
# review_scores_location             90.0       100.0        100.0        100.0
# review_scores_value                90.0        90.0        100.0        100.0
# reviews_per_month                  17.0        57.0        177.0       1291.0

# %%
# Resumen estadístico de las columnas no numéricas
df.describe(include = object).transpose()
# Out:
#                        count unique  \
# name                    6998   6755
# description             6972   6790
# neighbourhood_name      7001    478
# neighbourhood_district  4241     61
# room_type               7001      4
# amenities_list          6984   6792
# has_availability        6451      1
# first_review_date       5747   1793
# last_review_date        5746   1459
# is_instant_bookable     7001      2
# country                 7001      1
# city                    7001      8
# insert_date             7001    164
#
#                                                                       top  \
# name                    Beautiful two bedroom appartment with comunita...
# description             This apartment is part of a nice and well kept...
# neighbourhood_name                                 la Dreta de l'Eixample
# neighbourhood_district                                           Eixample
# room_type                                                 Entire home/apt
# amenities_list          TV,Wifi,Air conditioning,Kitchen,Elevator,Heat...
# has_availability                                                VERDADERO
# first_review_date                                              01/04/2018
# last_review_date                                               08/03/2020
# is_instant_bookable                                             VERDADERO
# country                                                             spain
# city                                                            barcelona
# insert_date                                                    14/05/2018
#
#                         freq
# name                       4
# description                4
# neighbourhood_name       262
# neighbourhood_district   786
# room_type               4979
# amenities_list             9
# has_availability        6451
# first_review_date         27
# last_review_date          28
# is_instant_bookable     3740
# country                 7001
# city                    2127
# insert_date              136

# %%
# Revisar valores faltantes
missing = df.isnull().sum().sort_values(ascending=False)
missing_percentage = (missing / len(df)) * 100

pd.DataFrame({
    "Cantidad de Valores Faltantes": missing,
    "Porcentaje de Valores Faltantes (%)": missing_percentage
})
# Out:
#                              Cantidad de Valores Faltantes  \
# neighbourhood_district                                2760
# review_scores_value                                   1342
# review_scores_location                                1342
# review_scores_checkin                                 1341
# review_scores_accuracy                                1336
# review_scores_communication                           1332
# review_scores_cleanliness                             1330
# review_scores_rating                                  1327
# last_review_date                                      1255
# reviews_per_month                                     1254
# first_review_date                                     1254
# has_availability                                       550
# price                                                  131
# bathrooms                                               32
# description                                             29
# bedrooms                                                29
# amenities_list                                          17
# beds                                                     3
# name                                                     3
# apartment_id                                             0
# availability_90                                          0
# availability_30                                          0
# maximum_nights                                           0
# minimum_nights                                           0
# neighbourhood_name                                       0
# host_id                                                  0
# accommodates                                             0
# room_type                                                0
# availability_60                                          0
# number_of_reviews                                        0
# availability_365                                         0
# is_instant_bookable                                      0
# country                                                  0
# city                                                     0
# insert_date                                              0
#
#                              Porcentaje de Valores Faltantes (%)
# neighbourhood_district                                 39.422940
# review_scores_value                                    19.168690
# review_scores_location                                 19.168690
# review_scores_checkin                                  19.154407
# review_scores_accuracy                                 19.082988
# review_scores_communication                            19.025853
# review_scores_cleanliness                              18.997286
# review_scores_rating                                   18.954435
# last_review_date                                       17.926011
# reviews_per_month                                      17.911727
# first_review_date                                      17.911727
# has_availability                                        7.856021
# price                                                   1.871161
# bathrooms                                               0.457078
# description                                             0.414227
# bedrooms                                                0.414227
# amenities_list                                          0.242822
# beds                                                    0.042851
# name                                                    0.042851
# apartment_id                                            0.000000
# availability_90                                         0.000000
# availability_30                                         0.000000
# maximum_nights                                          0.000000
# minimum_nights                                          0.000000
# neighbourhood_name                                      0.000000
# host_id                                                 0.000000
# accommodates                                            0.000000
# room_type                                               0.000000
# availability_60                                         0.000000
# number_of_reviews                                       0.000000
# availability_365                                        0.000000
# is_instant_bookable                                     0.000000
# country                                                 0.000000
# city                                                    0.000000
# insert_date                                             0.000000

# %% [markdown]
# **4. Visualización inicial**

# %%
# Sleccionar las columnas no necessarias para la visualización por cada columna,
# porque o (1) no tiene sendido hacerlo,
# o (2) tienen demasidas categorias que no nos interesan de momento
cols_excluir = ["apartment_id", "name", "description", "host_id",
                "neighbourhood_name", "neighbourhood_district", "amenities_list",
                "first_review_date", "last_review_date", "insert_date"]

# %% [markdown]
# **4.1 Visualización: histplots de las columnas numéricas**

# %%
# sleccionar las columnas numéricas
cols_num = df.select_dtypes(include='number').columns
cols_num = [x for x in cols_num if x not in cols_excluir]

# Cuántas columnas?
print(len(cols_num), "columnas numéricas para visualizar.")
# Out:
# 20 columnas numéricas para visualizar.

# %%
# Histplots de las columnas numéricas
for col in cols_num:
    sns.histplot(data=df, x = col, bins=30)
    plt.title(f'Histplot: {col}')
    plt.show()

# %% [markdown]
# **4.2 Visualización: countplots de las columnas no numéricas (recuento por categoria)**

# %%
# sleccionar las columnas no numéricas
cols_nonum = df.select_dtypes(include='object').columns
cols_nonum = [x for x in cols_nonum if x not in cols_excluir]

# Cuántas columnas?
print(len(cols_nonum), "columnas no numéricas para visualizar.")
# Out:
# 5 columnas no numéricas para visualizar.

# %%
# Countplots de las columnas no numéricas
for col in cols_nonum:
    sns.countplot(data=df, x=col)
    plt.title(f'Countplot: {col}')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# **4.3 Visualización: boxplots para identificar outliers en columnas interesantes**

# %%
numeric_columns = ['price', 'accommodates', 'beds', 'bedrooms']

for col in numeric_columns:
    plt.figure(figsize=(8,5))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot: {col}")
    plt.xlabel(col)
    plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='room_type', y='price', data=df)
plt.title("Precio según el Tipo de Habitación")
plt.xlabel("Tipo de Habitación")
plt.ylabel("Precio")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **4.4 Visualización: Precio medio por ciudad**

# %%
(
    df.groupby('city')['price']
      .mean()
      .sort_values(ascending=False)
      .round(2)
      .plot(
          kind='bar',
          figsize=(8, 6),
          color='green'
      )
)

plt.xlabel("Ciudad")
plt.ylabel("Precio medio")
plt.title("Precio medio por ciudad")
plt.show()

# %% [markdown]
# **4.5 Correlaciones entre los variables numericos**

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])


numeric_df = numeric_df.drop(columns=['apartment_id', 'host_id'], errors='ignore')

corr = numeric_df.corr()

plt.figure(figsize=(10,8))
sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    annot_kws={"size": 8},
    center=0,
    vmin=-1,
    vmax=1
)
plt.title("Correlaciones entre los valores numericos")
plt.show()
