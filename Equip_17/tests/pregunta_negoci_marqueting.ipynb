# %%
import pandas as pd

# %%
df = pd.read_pickle("staySpain_cleaned.pkl")

# %% [markdown]
# preu mitjà per tipus d'allotjament a cada ciutat

# %%
# Create crosstab with mean price
mean_price_per_room_type_and_city = pd.crosstab(index=df['city'], columns=df['room_type'], values=df['price'], aggfunc='mean')

# Display the crosstab
display(mean_price_per_room_type_and_city)
# Out:
# room_type  Entire home/apt   Hotel room  Private room  Shared room
# city
# barcelona      1300.936491  1444.285714    455.051740   371.875000
# girona         1230.680473   625.000000    602.115385          NaN
# madrid          942.631579   902.500000    372.805907   313.333333
# malaga          815.776173   703.333333    356.727273   143.333333
# mallorca       1709.567511  1401.666667    700.253165   493.333333
# menorca        1656.532258          NaN    610.000000          NaN
# sevilla        1033.908046   918.571429    606.000000   120.000000
# valencia        796.625000   955.000000    340.153846   203.333333
