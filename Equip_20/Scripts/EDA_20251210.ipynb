# %% [markdown]
# ### EDA Encuesta Anual Laboral (EAL)

# %%
# Importar las tablas a trabajar en el análisis exploratorio.

import pandas as pd

df_empresas_formadoras = pd.read_csv(r"C:\Users\jprom\Desktop\Projecte\ProjecteData\Equip_20\Data\EAL_Emp_formadoras_2018_2023.csv")

df_necesidades = pd.read_csv(r"C:\Users\jprom\Desktop\Projecte\ProjecteData\Equip_20\Data\EAL_Necesidades_2018_2023.csv")

df_competencias = pd.read_csv(r"C:\Users\jprom\Desktop\Projecte\ProjecteData\Equip_20\Data\EAL_Competencias_2018_2023.csv")

df_limitaciones = pd.read_csv(r"C:\Users\jprom\Desktop\Projecte\ProjecteData\Equip_20\Data\EAL_Limitacion_2018_2023.csv")

df_medios = pd.read_csv(r"C:\Users\jprom\Desktop\Projecte\ProjecteData\Equip_20\Data\EAL_Medio_2018_2023.csv")

df_no_formativos = pd.read_csv(r"C:\Users\jprom\Desktop\Projecte\ProjecteData\Equip_20\Data\EAL_No_Forman_2018_2023.csv")

# %%
# 1. Eliminar el '%', reemplazar ',' por '.' y convertir a float (número decimal)
df_empresas_formadoras['Emp. 250 a 499'] = df_empresas_formadoras['Emp. 250 a 499'].str.rstrip('%').str.replace(',', '.').astype(float)

df_empresas_formadoras['AE Transporte y alm.'] = df_empresas_formadoras['AE Transporte y alm.'].str.rstrip('%').str.replace(',', '.').astype(float)

df_empresas_formadoras['C.A. Catalunya'] = df_empresas_formadoras['C.A. Catalunya'].str.rstrip('%').str.replace(',', '.').astype(float)

# %%
df_empresas_formadoras
# Out:
#     Año  Emp. 250 a 499  AE Transporte y alm.  C.A. Catalunya
# 0  2018            99.7                  82.4            77.1
# 1  2019            99.3                  83.5            78.4
# 2  2020            96.1                  68.2            60.6
# 3  2021            96.0                  73.0            67.9
# 4  2022            96.4                  76.6            74.8
# 5  2023            98.3                  79.6            74.5

# %%
# 1. Eliminar el '%', reemplazar ',' por '.' y convertir a float (número decimal)
df_necesidades['Emp. 250 a 499'] = df_necesidades['Emp. 250 a 499'].str.rstrip('%').str.replace(',', '.').astype(float)

df_necesidades['AE Transporte y alm.'] = df_necesidades['AE Transporte y alm.'].str.rstrip('%').str.replace(',', '.').astype(float)

df_necesidades['C.A. Catalunya'] = df_necesidades['C.A. Catalunya'].str.rstrip('%').str.replace(',', '.').astype(float)

# %%
df_necesidades
# Out:
#     Año  Emp. 250 a 499  AE Transporte y alm.  C.A. Catalunya
# 0  2018            80.1                  31.8            39.6
# 1  2019            77.0                  28.9            38.7
# 2  2020            77.0                  29.1            33.2
# 3  2021            48.0                  19.0            17.1
# 4  2022            59.5                  22.3            27.3
# 5  2023            64.3                  26.0            32.4

# %%
# 1. Eliminar el '%', reemplazar ',' por '.' y convertir a float (número decimal)
df_competencias['Emp. 250 a 499'] = df_competencias['Emp. 250 a 499'].str.rstrip('%').str.replace(',', '.').astype(float)

df_competencias['C.A. Catalunya'] = df_competencias['C.A. Catalunya'].str.rstrip('%').str.replace(',', '.').astype(float)

df_competencias['Servicios'] = df_competencias['Servicios'].str.rstrip('%').str.replace(',', '.').astype(float)

# %%
df_competencias.head()
# Out:
#     Año             Tipo  Emp. 250 a 499  Servicios  C.A. Catalunya
# 0  2018      Específicas            52.8       35.7            36.8
# 1  2018         Atención            24.8       35.0            28.9
# 2  2018           Equipo            29.8       24.2            27.0
# 3  2018            Otras            17.0       19.0            18.6
# 4  2018  Administrativas            12.5       17.0            15.7

# %%
# 1. Eliminar el '%', reemplazar ',' por '.' y convertir a float (número decimal)
df_limitaciones['Nada'] = df_limitaciones['Nada'].str.rstrip('%').str.replace(',', '.').astype(float)

df_limitaciones['Poco'] = df_limitaciones['Poco'].str.rstrip('%').str.replace(',', '.').astype(float)

df_limitaciones['Bastante'] = df_limitaciones['Bastante'].str.rstrip('%').str.replace(',', '.').astype(float)

df_limitaciones['Mucho'] = df_limitaciones['Mucho'].str.rstrip('%').str.replace(',', '.').astype(float)

# %%
df_limitaciones.head()
# Out:
#     Año           Motivo  Nada  Poco  Bastante  Mucho
# 0  2018        Apropiado  13.2  29.5      44.7   12.6
# 1  2018      Cualificado  23.9  27.5      37.9   10.7
# 2  2018  Dificultad_Eval  32.1  52.6      13.6    1.6
# 3  2018     Falta_cursos  25.8  42.4      23.3    8.4
# 4  2018       Alto_coste  19.5  35.7      30.9   13.9

# %%
# 1. Eliminar el '%', reemplazar ',' por '.' y convertir a float (número decimal)
df_medios['Porcentaje_x_tamaño'] = df_medios['Porcentaje_x_tamaño'].str.rstrip('%').str.replace(',', '.').astype(float)

df_medios['Porcentaje_x_A_E'] = df_medios['Porcentaje_x_A_E'].str.rstrip('%').str.replace(',', '.').astype(float)

df_medios['Catalunya'] = df_medios['Catalunya'].str.rstrip('%').str.replace(',', '.').astype(float)

# %%
df_medios
# Out:
#     Año            Tipo  Porcentaje_x_tamaño  Porcentaje_x_A_E  Catalunya
# 0  2023   Diseño_propio                 75.8              23.8       26.6
# 1  2023  Diseño_externo                 83.2              62.4       53.4
# 2  2023         On_site                 75.6              42.2       44.5
# 3  2023     Intercambio                 41.3              16.0       20.1
# 4  2023        Externos                 59.9              13.8       30.4

# %%
# 1. Eliminar el '%', reemplazar ',' por '.' y convertir a float (número decimal)
df_no_formativos['Nada'] = df_no_formativos['Nada'].str.rstrip('%').str.replace(',', '.').astype(float)

df_no_formativos['Poco'] = df_no_formativos['Poco'].str.rstrip('%').str.replace(',', '.').astype(float)

df_no_formativos['Bastante'] = df_no_formativos['Bastante'].str.rstrip('%').str.replace(',', '.').astype(float)

df_no_formativos['Mucho'] = df_no_formativos['Mucho'].str.rstrip('%').str.replace(',', '.').astype(float)

# %%
df_no_formativos.head()
# Out:
#     Año            Motivo  Nada  Poco  Bastante  Mucho
# 0  2018         Apropiado  11.4  15.5      45.4   27.7
# 1  2018       Cualificado  19.4  15.8      44.6   20.2
# 2  2018      Carga_tiempo  21.1  28.3      32.5   18.1
# 3  2018  Sin_subvenciones  26.4  34.4      24.4   14.8
# 4  2018        Alto_coste  30.3  34.5      25.1   10.1

# %% [markdown]
# ### Visualizaciones EDA

# %%
# Importamos las librerías a emplear en las visualizaciones
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Configuración básica para los gráficos
sns.set_style("whitegrid")
plt.rcParams['figure.dpi'] = 100 # Mejora de la resolución de los gráficos
# Paleta de colores Seaborn Set2, para usarla con MatPlotLib y seguir el mismo estilo
sns_color_set2 = ["#66c2a5", "#fc8d62", "#8da0cb", "#e78ac3", "#a6d854", "#ffd92f", "#e5c494", "#b3b3b3"]

# %% [markdown]
# ##### Gráfico de Empresas Formadoras por Tamaño, Actividad y Comunidad

# %%
# Crear el gráfico de lineas
plt.figure(figsize=(12, 6))
sns.lineplot(
    data=df_empresas_formadoras.melt(id_vars='Año', var_name='Categoría', value_name='Porcentaje'),
    x='Año',
    y='Porcentaje',
    hue='Categoría',
    palette='Set2'
)

# Añadir etiquetas y título
plt.title('Empresas Formadoras por Tamaño, Actividad y Comunidad', fontsize=16)
plt.xlabel('Año', fontsize=14)
plt.ylabel('Porcentaje sobre el total de empresas', fontsize=14)

# Rotar las etiquetas del eje X para que sean legibles
plt.xticks(rotation=45, ha='right')

plt.tight_layout() # Ajustar el diseño para que todo quepa
plt.show()

# %% [markdown]
# ##### Gráfico de Necesidades Formativas por Tamaño, Actividad y Comunidad

# %%
# Crear el gráfico de barras
plt.figure(figsize=(12, 6))
ax = sns.barplot(
    data=df_necesidades.melt(id_vars='Año', var_name='Categoría', value_name='Porcentaje'),
    x='Año',
    y='Porcentaje',
    hue='Categoría',
    palette='Set2'
)

# Añadir las etiquetas directamente sobre las barras (filtrar patches que no tienen get_height)
for p in ax.patches:
    # Algunos elementos en ax.patches no tienen get_height (p.ej. PathPatch u otros), por eso verificamos
    if not hasattr(p, "get_height"):
        continue
    height = p.get_height() # type: ignore
    # Evitar anotar valores NaN
    if np.isnan(height):
        continue
    ax.annotate(f'{height:.2f}%',
                xy=(p.get_x() + p.get_width() / 2, height), # type: ignore
                xytext=(0, 3),
                textcoords='offset points',
                ha='center', va='bottom',
                fontsize=9, color='dimgray')

# Añadir etiquetas y título
plt.title('Necesidades Formativas por Tamaño de la empresa, Actividad y Comunidad', fontsize=16)
plt.xlabel('Año', fontsize=14)
plt.ylabel('Porcentaje sobre el total de empresas', fontsize=14)

# Rotar las etiquetas del eje X para que sean legibles
plt.xticks(rotation=45, ha='right')

plt.tight_layout() # Ajustar el diseño para que todo quepa
plt.show()

# %% [markdown]
# ##### Gráfico de serie temporal de Competencias Formativas

# %%
#  Reestructurar los datos a formato "largo" (tidy data)
# Este paso es CRUCIAL para usar Seaborn FacetGrid o catplot/relplot de manera efectiva.
df_long = df_competencias.melt(
    id_vars=['Año', 'Tipo'],
    var_name='Categoría',
    value_name='Porcentaje'
)

# Definición de la visualización robusta (Small Multiples con Seaborn)

# Configuración del estilo
sns.set_theme(style="whitegrid")

# Creación de los múltiples gráficos de línea (Small Multiples)
# relplot es ideal para series temporales y usa FacetGrid para crear el layout.
g = sns.relplot(
    data=df_long,
    x='Año',
    y='Porcentaje',
    # 'col' divide los gráficos por 'Tipo' de competencia
    col='Tipo',
    # 'hue' traza las líneas individuales para cada 'Categoría'
    hue='Categoría',
    kind='line',
    # Definición de la cuadrícula (e.g., 2 filas para los 5 tipos)
    col_wrap=3,
    height=4, 
    aspect=1.2, # Ajuste de la proporción ancho/alto
    palette='Set2',
    marker='o', # Añadir marcadores para visualizar los puntos de datos discretos (años)
    dashes=False # Usar líneas sólidas
)

# Personalización del gráfico

# Título general
g.figure.suptitle('Evolución Anual (2018-2023) de los Tipos de Competencia por Categoría', 
                  fontsize=16, fontweight='bold', y=1.03)

# Etiquetas y formato de los ejes
for ax in g.axes.flat:
    # Formato de eje X para mostrar años completos
    ax.set_xticks(df_competencias['Año'].unique())
    ax.set_xticklabels(df_competencias['Año'].unique().astype(str), rotation=45, ha='right')
    
    # Añadir el símbolo de porcentaje al eje Y
    ax.set_ylabel('Porcentaje (%)', fontsize=10)
    ax.set_xlabel('Año', fontsize=10)
    
    # Ajustar el título de cada subgráfico (el 'Tipo' de competencia)
    new_title = ax.get_title().split(' = ')[-1]
    ax.set_title(new_title, fontsize=12, fontweight='semibold')
    
    # Mejorar la leyenda (se añade automáticamente por relplot)
    if ax.get_legend() is not None:
        ax.get_legend().set_title('Categoría')
        
# Ajustar el layout
plt.tight_layout(rect=(0, 0, 1, 0.98)) # Usar tuple para evitar error de tipos y dejar espacio al suptitle

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Gráfico de Top 5 de competencias clave del sector servicios

# %%
servicios = df_competencias.loc[:,['Año','Tipo','Servicios']]
servicios
# Out:
#      Año             Tipo  Servicios
# 0   2018      Específicas       35.7
# 1   2018         Atención       35.0
# 2   2018           Equipo       24.2
# 3   2018            Otras       19.0
# 4   2018  Administrativas       17.0
# ..   ...              ...        ...
# 61  2023              TIC       12.8
# 62  2023        Dirección       11.6
# 63  2023          Lenguas        9.1
# 64  2023               IT        7.4
# 65  2023          Básicas        2.3
#
# [66 rows x 3 columns]

# %%
plt.figure(figsize=(12, 6))
# 'servicios' ya contiene las columnas 'Año', 'Tipo' y 'Servicios'
sns.lineplot(
    data=servicios,
    x='Año',
    y='Servicios',
    hue='Tipo',
    palette='Set2',
    marker='o'
)

# Añadir etiquetas y título
plt.title('Competencias por sector Servicios', fontsize=16)
plt.xlabel('Año', fontsize=14)
plt.ylabel('Porcentaje sobre el total de empresas', fontsize=14)

# Rotar las etiquetas del eje X para que sean legibles
plt.xticks(rotation=45, ha='right')

plt.tight_layout() # Ajustar el diseño para que todo quepa
plt.show()

# %% [markdown]
# ##### Gráfico de serie temporal de Limitaciones Formativas

# %%
#  Reestructurar los datos a formato "largo" (tidy data)
# Este paso es CRUCIAL para usar Seaborn FacetGrid o catplot/relplot de manera efectiva.
df_long = df_limitaciones.melt(
    id_vars=['Año', 'Motivo'],
    var_name='Categoría',
    value_name='Porcentaje'
)

# Definición de la visualización robusta (Small Multiples con Seaborn)

# Configuración del estilo
sns.set_theme(style="whitegrid")

# Creación de los múltiples gráficos de línea (Small Multiples)
# relplot es ideal para series temporales y usa FacetGrid para crear el layout.
g = sns.relplot(
    data=df_long,
    x='Año',
    y='Porcentaje',
    # 'col' divide los gráficos por 'Motivo' de limitaciones
    col='Motivo',
    # 'hue' traza las líneas individuales para cada 'Categoría'
    hue='Categoría',
    kind='line',
    # Definición de la cuadrícula (e.g., 2 filas para los 5 tipos)
    col_wrap=3,
    height=4, 
    aspect=1.2, # Ajuste de la proporción ancho/alto
    palette='Set2',
    marker='o', # Añadir marcadores para visualizar los puntos de datos discretos (años)
    dashes=False # Usar líneas sólidas
)

# Personalización del gráfico

# Título general
g.figure.suptitle('Evolución Anual (2018-2023) de las Limitaciones Formativas por Categoría', 
                  fontsize=16, fontweight='bold', y=1.03)

# Etiquetas y formato de los ejes
for ax in g.axes.flat:
    # Formato de eje X para mostrar años completos
    ax.set_xticks(df_competencias['Año'].unique())
    ax.set_xticklabels(df_competencias['Año'].unique().astype(str), rotation=45, ha='right')
    
    # Añadir el símbolo de porcentaje al eje Y
    ax.set_ylabel('Porcentaje (%)', fontsize=10)
    ax.set_xlabel('Año', fontsize=10)
    
    # Ajustar el título de cada subgráfico (el 'Tipo' de competencia)
    new_title = ax.get_title().split(' = ')[-1]
    ax.set_title(new_title, fontsize=12, fontweight='semibold')
    
    # Mejorar la leyenda (se añade automáticamente por relplot)
    if ax.get_legend() is not None:
        ax.get_legend().set_title('Categoría')
        
# Ajustar el layout
plt.tight_layout(rect=(0, 0, 1, 0.98)) # Usar tuple para evitar error de tipos y dejar espacio al suptitle

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ##### Gráfico de barras agrupadas de Medios Formativos por Tipo y Categorías

# %%
# Reestructurar los datos a formato "largo" (tidy data) para facilitar la visualización
# 'melt' transforma las columnas de categorías en filas.
df= df_medios.melt(
    id_vars='Tipo',
    var_name='Categorías',
    value_name='Porcentaje'
)

# 3. Definición de la visualización robusta con Matplotlib

# Configuración del estilo
plt.style.use('seaborn-v0_8-whitegrid') # Un estilo limpio y profesional

# Creación de la figura y los ejes
fig, ax = plt.subplots(figsize=(12, 7))

# Definición de la posición de las barras
tipos = df['Tipo'].unique()
x = np.arange(len(tipos)) # Posiciones de las etiquetas 'Tipo'
width = 0.25 # Ancho de las barras

# Nombres de las categorías (columnas a graficar)
categorias = ['Porcentaje_x_tamaño', 'Porcentaje_x_A_E', 'Catalunya']

# Generación de las barras para cada categoría
# Utilizamos un bucle for para automatizar el desplazamiento de las barras (offset)
for i, cat in enumerate(categorias):
    # Extraer los datos de la categoría actual
    porcentajes = df[df['Categorías'] == cat]['Porcentaje']
    
    # Calcular la posición de las barras (desplazamiento para agrupar)
    offset = (i - 1) * width
    
    # Dibujar las barras
    rects = ax.bar(x + offset, porcentajes, width, label=cat, zorder=3)
    
    # Añadir las etiquetas de valor (data labels) para mayor precisión
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.1f}%',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 puntos de desplazamiento vertical
                    textcoords="offset points",
                    ha='center', va='bottom',
                    fontsize=9,
                    color='dimgray')

# 4. Personalización del gráfico

# Título y etiquetas
ax.set_title('Distribución de Medios Formativos por Tipo y Categorías (2023)', 
             fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Tipo de Medio', fontsize=12)
ax.set_ylabel('Porcentaje sobre el total de empresas', fontsize=12)

# Etiquetas del eje X
ax.set_xticks(x)
ax.set_xticklabels(tipos, rotation=45, ha="right", fontsize=10) # Rotación para mejor legibilidad

# Leyenda
ax.legend(title='Categoría', loc='upper right', bbox_to_anchor=(1.0, 1.0))

# Ajustar diseño para evitar el recorte de etiquetas
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ##### Gráfico de serie temporal de Motivos No Formativos

# %%
#  Reestructurar los datos a formato "largo" (tidy data)
# Este paso es CRUCIAL para usar Seaborn FacetGrid o catplot/relplot de manera efectiva.
df_long = df_no_formativos.melt(
    id_vars=['Año', 'Motivo'],
    var_name='Categoría',
    value_name='Porcentaje'
)

# Definición de la visualización robusta (Small Multiples con Seaborn)

# Configuración del estilo
sns.set_theme(style="whitegrid")

# Creación de los múltiples gráficos de línea (Small Multiples)
# relplot es ideal para series temporales y usa FacetGrid para crear el layout.
g = sns.relplot(
    data=df_long,
    x='Año',
    y='Porcentaje',
    # 'col' divide los gráficos por 'Motivo' de no formación
    col='Motivo',
    # 'hue' traza las líneas individuales para cada 'Categoría'
    hue='Categoría',
    kind='line',
    # Definición de la cuadrícula (e.g., 2 filas para los 5 tipos)
    col_wrap=3,
    height=4, 
    aspect=1.2, # Ajuste de la proporción ancho/alto
    palette='Set2',
    marker='o', # Añadir marcadores para visualizar los puntos de datos discretos (años)
    dashes=False # Usar líneas sólidas
)

# Personalización del gráfico

# Título general
g.figure.suptitle('Evolución Anual (2018-2023) de los Motivos No Formativos por Categoría', 
                  fontsize=16, fontweight='bold', y=1.03)

# Etiquetas y formato de los ejes
for ax in g.axes.flat:
    # Formato de eje X para mostrar años completos
    ax.set_xticks(df_competencias['Año'].unique())
    ax.set_xticklabels(df_competencias['Año'].unique().astype(str), rotation=45, ha='right')
    
    # Añadir el símbolo de porcentaje al eje Y
    ax.set_ylabel('Porcentaje (%)', fontsize=10)
    ax.set_xlabel('Año', fontsize=10)
    
    # Ajustar el título de cada subgráfico (el 'Motivo' de no formación)
    new_title = ax.get_title().split(' = ')[-1]
    ax.set_title(new_title, fontsize=12, fontweight='semibold')
    
    # Mejorar la leyenda (se añade automáticamente por relplot)
    if ax.get_legend() is not None:
        ax.get_legend().set_title('Categoría')
        
# Ajustar el layout
plt.tight_layout(rect=(0, 0, 1, 0.98)) # Usar tuple para evitar error de tipos y dejar espacio al suptitle

# Mostrar el gráfico
plt.show()
