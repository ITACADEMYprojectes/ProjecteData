# %%
import pandas as pd
import seaborn as sns
import numpy as np

df = pd.read_csv("data_cleaning_2026_20_04.csv")

# %%
df
# Out:
#      ID  Reason_absence  Month_absence   Day_week Seasons  \
# 0    14              11           11.0     Monday  spring
# 1    36              13            4.0  Wednesday  winter
# 2     9               6            7.0    Tuesday  summer
# 3    28               9            7.0    Tuesday  summer
# 4     9              12            3.0    Tuesday  autumn
# ..   ..             ...            ...        ...     ...
# 701   2               0            6.0     Monday  winter
# 702  21               0            6.0     Monday  winter
# 703   4               0            NaN    Tuesday  summer
# 704   8               0            NaN  Wednesday  autumn
# 705  35               0            NaN     Friday  winter
#
#      Transportation_expense  Distance_Residence_Work  Service_time  Age  \
# 0                       155                       12            14   34
# 1                       118                       13            18   50
# ...

# %%
df.groupby()
