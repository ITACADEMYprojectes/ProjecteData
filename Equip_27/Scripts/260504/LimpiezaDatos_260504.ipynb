# %% [markdown]
# # Data Cleaning —
# **Proyecto:** Simulació Empresarial IT Academy — Bank Marketing
#
# **Variables asignadas 20/4/26, Andrey:** `age`, `job`, `marital`, `education`, `default`, `balance`, `housing`, `loan`, `contact`
#
# **Variables asignadas 20/4/26, Margot:** `day`, `month`, `duration`, `campaign`, `pdays`, `previous`, `poutcome`, `deposit`
#
# *El documento se sigue trabajando con esta división*
#
# **Áreas cubiertas:** 1-Nulos · 2-Duplicados · 3-Outliers · 4-Estandarización · 5-Tipos de dato

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Lectura del archivo

# %%
df = pd.read_csv("../../data/df_original_260504.csv")

# %%
if 'id' in df.columns: df.set_index('id', inplace=True)
df.head(5)
# Out:
#     age         job  marital  education default  balance housing loan  \
# 0  59.0      admin.  married  secondary      no     2343     yes   no
# 1  56.0      admin.  married  secondary      no       45      no   no
# 2  41.0  technician  married  secondary      no     1270     yes   no
# 3  55.0    services  married  secondary      no     2476     yes   no
# 4  54.0      admin.  married   tertiary      no      184      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may      1042         1     -1         0  unknown     yes
# 1  unknown    5   may      1467         1     -1         0  unknown     yes
# 2  unknown    5   may      1389         1     -1         0  unknown     yes
# 3  unknown    5   may       579         1     -1         0  unknown     yes
# 4  unknown    5   may       673         2     -1         0  unknown     yes

# %%
print(f'El dataset cuenta con {df.shape[0]} regisrtos y {df.shape[1]} variables.')
# Out:
# El dataset cuenta con 11162 regisrtos y 17 variables.

# %% [markdown]
# ## Variables, valores unicos, tipo, ejemplos de valores

# %%
variables = pd.DataFrame(columns=['Variable', 'Número de valores unicos', 'Tipo','Valores'])
for i, var in enumerate(df.columns):
    variables.loc[i] = [var, df[var].nunique(), df[var].dtype,df[var].unique().tolist()]

variables
# Out:
#      Variable  Número de valores unicos     Tipo  \
# 0         age                        76  float64
# 1         job                        12   object
# 2     marital                         3   object
# 3   education                         4   object
# 4     default                         2   object
# 5     balance                      3805    int64
# 6     housing                         2   object
# 7        loan                         2   object
# 8     contact                         3   object
# 9         day                        31    int64
# 10      month                        12   object
# 11   duration                      1428    int64
# 12   campaign                        36    int64
# 13      pdays                       472    int64
# 14   previous                        34    int64
# 15   poutcome                         4   object
# 16    deposit                         2   object
#
#                                               Valores
# 0   [59.0, 56.0, 41.0, 55.0, 54.0, 42.0, 60.0, 37....
# 1   [admin., technician, services, management, ret...
# 2                    [married, single, divorced, nan]
# 3        [secondary, tertiary, primary, unknown, nan]
# 4                                           [no, yes]
# 5   [2343, 45, 1270, 2476, 184, 0, 830, 545, 1, 50...
# 6                                           [yes, no]
# 7                                           [no, yes]
# 8                      [unknown, cellular, telephone]
# 9   [5, 6, 7, 8, 9, 12, 13, 14, 15, 16, 19, 20, 21...
# 10  [may, jun, jul, aug, oct, nov, dec, jan, feb, ...
# 11  [1042, 1467, 1389, 579, 673, 562, 1201, 1030, ...
# 12  [1, 2, 3, 4, 6, 5, 8, 11, 9, 10, 15, 12, 14, 7...
# 13  [-1, 166, 91, 147, 170, 150, 171, 126, 182, 11...
# 14  [0, 1, 4, 2, 3, 10, 7, 9, 5, 29, 6, 13, 17, 8,...
# 15                 [unknown, other, failure, success]
# 16                                          [yes, no]

# %% [markdown]
# ## Revisión de valores nulos

# %%
# Valores nulos por variable
nulos = df.isnull().sum()

# Calcular el porcentaje de nulos
nulos_porcentaje = (nulos / len(df)) * 100

null_info = pd.DataFrame({
    'Variable': nulos.index,
    'Nulos': nulos.values,
    'Porcentaje de Nulos': nulos_porcentaje.values
})

null_info
# Out:
#      Variable  Nulos  Porcentaje de Nulos
# 0         age     10             0.089590
# 1         job      0             0.000000
# 2     marital      5             0.044795
# 3   education      7             0.062713
# 4     default      0             0.000000
# 5     balance      0             0.000000
# 6     housing      0             0.000000
# 7        loan      0             0.000000
# 8     contact      0             0.000000
# 9         day      0             0.000000
# 10      month      0             0.000000
# 11   duration      0             0.000000
# 12   campaign      0             0.000000
# 13      pdays      0             0.000000
# 14   previous      0             0.000000
# 15   poutcome      0             0.000000
# 16    deposit      0             0.000000

# %% [markdown]
# Variables **age**, **marital**, **education** presentan valores nulos.
# - **age** : 10 (0.09%)
# - **marital** : 5 (0.05%)
# - **education**: 7 (0.06%)

# %% [markdown]
# Filas con valores nulos

# %%
df_nulos = df[df.isna().any(axis=1)]
print(df_nulos.shape)
df_nulos
# Out:
# (22, 17)
#         age           job   marital  education default  balance housing loan  \
# 1088   53.0    management       NaN  secondary      no     1004      no  yes
# 1181    NaN    management   married   tertiary      no      309     yes   no
# 1300   37.0    technician   married        NaN      no      549      no   no
# 1410    NaN   blue-collar   married    primary      no     4979      no   no
# 2943   24.0       student    single        NaN      no      382      no   no
# 3719   68.0       retired       NaN  secondary      no     4189      no   no
# 4019    NaN      services    single  secondary      no     1934      no   no
# 4737   37.0    management    single        NaN      no      102     yes   no
# 4854   34.0    management       NaN   tertiary      no        5      no   no
# 5680    NaN    technician    single   tertiary      no      720      no   no
# 6701   60.0        admin.       NaN    primary      no     -444      no  yes
# 6763    NaN    technician    single   tertiary      no      686     yes   no
# 6819   32.0      services   married        NaN      no     -344      no  yes
# 7121   57.0  entrepreneur   married        NaN      no      657      no   no
# 8419    NaN   blue-collar   married  secondary      no     1782     yes   no
# 8592   55.0    management    single        NaN      no      797      no   no
# 9272   30.0   blue-collar       NaN    primary      no       35     yes   no
# 9406   32.0    technician    single        NaN      no      696      no  yes
# 9470    NaN    management   married   tertiary      no      552      no   no
# 9552    NaN        admin.   married  secondary      no     1648     yes   no
# 9751    NaN      services   married    primary      no     2567     yes   no
# 10678   NaN    technician  divorced   tertiary      no        0     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 1088   telephone   22   dec       119         1     -1         0  unknown
# 1181    cellular    5   feb       676         1     -1         0  unknown
# 1300    cellular    2   mar       239         1     -1         0  unknown
# 1410   telephone    6   apr       180         1     -1         0  unknown
# 2943    cellular   13   nov       256         2     92         3  failure
# 3719   telephone   14   jul       897         2     -1         0  unknown
# 4019    cellular   29   sep       271         1     -1         0  unknown
# 4737    cellular    6   may       445         1    258         2  failure
# 4854    cellular   18   aug       370         2     -1         0  unknown
# 5680    cellular   12   aug       234         4     -1         0  unknown
# 6701    cellular   16   jul       227         1     -1         0  unknown
# 6763     unknown   30   may        98         2     -1         0  unknown
# 6819    cellular    4   feb        44         1     -1         0  unknown
# 7121     unknown   12   jun       344         1     -1         0  unknown
# 8419     unknown   19   jun       549         1     -1         0  unknown
# 8592    cellular   29   jul        24         2     -1         0  unknown
# 9272    cellular   11   jul       366         2     -1         0  unknown
# 9406    cellular   13   aug       101         4    105         4  failure
# 9470    cellular   28   jul       761         8     -1         0  unknown
# 9552    cellular   19   nov       172         3     -1         0  unknown
# 9751    cellular   14   may       109         1    360         2  failure
# 10678   cellular    2   jun        72         1     -1         0  unknown
#
#       deposit
# 1088      yes
# 1181      yes
# 1300      yes
# 1410      yes
# 2943      yes
# 3719      yes
# 4019      yes
# 4737      yes
# 4854      yes
# 5680       no
# 6701       no
# 6763       no
# 6819       no
# 7121       no
# 8419       no
# 8592       no
# 9272       no
# 9406       no
# 9470       no
# 9552       no
# 9751       no
# 10678      no

# %% [markdown]
# ## Imputación de nulos

# %% [markdown]
# ##### Variable **age**: reemplazamos valores nulos por la mediana de **age** de grupos agrupados por las variables **education**,**marital**,**job**

# %%
mask_age = df[['education','marital']].notna().all(axis=1)

df.loc[mask_age, 'age'] = (
    df.loc[mask_age]
      .groupby(['education','marital','job'])['age']
      .transform(lambda x: x.fillna(x.median()))
)

# %% [markdown]
# #### Usar **age** exacta genera grupos pequeños por eso he dividido los valores por grupos

# %%
df['age_group'] = pd.cut(df['age'], bins=[0, 25, 35, 45, 55, 65, 120], include_lowest=True)

# %% [markdown]
# ##### Variable **marital**: reemplazamos valores nulos por la moda de **marital** de grupos agrupados por las variables **age_group**, **education**, **job**

# %%
mask_marital = df[['education']].notna().all(axis=1)

df.loc[mask_marital,'marital'] = (
    df.loc[mask_marital]
    .groupby(['age_group','education','job'])['marital']
    .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else np.nan))
)
# Out:
# /var/folders/jv/7q1fz7mx4p5cwq9vy_chsmxm0000gn/T/ipykernel_72647/4031764850.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['age_group','education','job'])['marital']

# %% [markdown]
# ##### Variable **education**: reemplazamos valores nulos por la moda de **education** de grupos agrupados por las variables **age_group**, **marital**, **job**

# %%
df['education'] = (
    df.groupby(['age_group','marital','job'])['education']
    .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else np.nan))
)
# Out:
# /var/folders/jv/7q1fz7mx4p5cwq9vy_chsmxm0000gn/T/ipykernel_72647/1809283470.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['age_group','marital','job'])['education']

# %% [markdown]
# #### Comprobamos que no hay valores nulos

# %%
df[['age', 'marital', 'education']].isnull().sum()
# Out:
# age          0
# marital      0
# education    0
# dtype: int64

# %%
if 'age_group' in df.columns: df.drop(columns='age_group', inplace=True)

# %% [markdown]
# ### Variable **age**

# %%
df['age'].describe()
# Out:
# count    11162.000000
# mean        41.233112
# std         11.910772
# min         18.000000
# 25%         32.000000
# 50%         39.000000
# 75%         49.000000
# max         95.000000
# Name: age, dtype: float64

# %%
df['age'].plot.hist(bins=100, figsize=(9,3));

# %%
df['age'].plot.box(figsize=(9,3), vert=False);

# %%
#Convertir edad a int:
df[df['age'] % 1 != 0] #para ver edades con decimales, hay un 45.5 que no tiene sentido
df['age'] = df['age'].astype(float).astype(int).astype('int64')

# %% [markdown]
# Datos estan concentados en el rango 30 - 50 años. Varible age presenta valores atipicos.

# %% [markdown]
# ### Variable **job**

# %%
df['job'].value_counts()
# Out:
# job
# management       2566
# blue-collar      1944
# technician       1823
# admin.           1334
# services          923
# retired           778
# self-employed     405
# student           360
# unemployed        357
# entrepreneur      328
# housemaid         274
# unknown            70
# Name: count, dtype: int64

# %% [markdown]
# ##### Cambia el tipo por string

# %%
df['job'] = df['job'].astype('string')

# %% [markdown]
# ##### Reemplazamos **admin.** por **administration**

# %%
df['job'] = df['job'].replace('admin.', 'administration')

# %% [markdown]
# ### Variable **marital**

# %%
df['marital'].value_counts()
# Out:
# marital
# married     6353
# single      3518
# divorced    1291
# Name: count, dtype: int64

# %% [markdown]
# ##### Cambia el tipo por string

# %%
df['marital'] = df['marital'].astype('string')

# %% [markdown]
# ### Variable **education**

# %%
df['education'].value_counts()
# Out:
# education
# secondary    5478
# tertiary     3688
# primary      1500
# unknown       496
# Name: count, dtype: int64

# %% [markdown]
# ##### Cambia el tipo por string

# %%
df['education'] = df['education'].astype('string')

# %% [markdown]
# ### Variable **default**

# %%
df['default'].value_counts()
# Out:
# default
# no     10994
# yes      168
# Name: count, dtype: int64

# %% [markdown]
# ##### Cambia el tipo por string

# %%
df['default'] = df['default'].astype('string')

# %% [markdown]
# ### Variable **balance**

# %%
df['balance'].describe()
# Out:
# count    11162.000000
# mean      1528.538524
# std       3225.413326
# min      -6847.000000
# 25%        122.000000
# 50%        550.000000
# 75%       1708.000000
# max      81204.000000
# Name: balance, dtype: float64

# %%
df['balance'].plot.hist(bins=100, figsize=(9,3));

# %%
df['balance'].plot.box(figsize=(9,3), vert=False);

# %% [markdown]
# ### Variable **housing**

# %%
df['housing'].value_counts()
# Out:
# housing
# no     5881
# yes    5281
# Name: count, dtype: int64

# %% [markdown]
# ##### Cambia el tipo por string

# %%
df['housing'] = df['housing'].astype('string')

# %% [markdown]
# ### Variable **loan**

# %%
df['loan'].value_counts()
# Out:
# loan
# no     9702
# yes    1460
# Name: count, dtype: int64

# %% [markdown]
# ##### Cambia el tipo por string

# %%
df['loan'] = df['loan'].astype('string')

# %% [markdown]
# ### Variable **contact**

# %%
df['contact'].value_counts()
# Out:
# contact
# cellular     8042
# unknown      2346
# telephone     774
# Name: count, dtype: int64

# %% [markdown]
# ##### Cambia el tipo por string

# %%
df['contact'] = df['contact'].astype('string')

# %% [markdown]
# ### Variable **poutcome**

# %%
df['poutcome'].value_counts()
# Out:
# poutcome
# unknown    8326
# failure    1228
# success    1071
# other       537
# Name: count, dtype: int64

# %% [markdown]
# ##### Cambia el tipo por string

# %%
df['poutcome'] = df['poutcome'].astype('string')

# %% [markdown]
# ### Variable **deposit**

# %%
df['deposit'].value_counts()
# Out:
# deposit
# no     5873
# yes    5289
# Name: count, dtype: int64

# %% [markdown]
# ##### Cambia el tipo por string

# %%
df['deposit'] = df['deposit'].astype('string')

# %% [markdown]
# ## Selección de variables
# Se trabaja directamente sobre `df`. Se seleccionan las 8 variables asignadas.

# %%
# df = pd.read_csv('df_original_260427.csv')

variables_fin = ['day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'deposit']
# df[['id'] + variables_fin].head()
df[variables_fin].head()
# Out:
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %% [markdown]
# ## Diagnóstico inicial
# Vista general antes de cualquier transformación: nulos, unknowns, estadísticas y duplicados.

# %%
# subset = df[['id'] + variables_fin]
subset = df[variables_fin]

# Nulos reales
print("Nulos por columna:")
print(subset.isnull().sum())
# Out:
# Nulos por columna:
# day         0
# month       0
# duration    0
# campaign    0
# pdays       0
# previous    0
# poutcome    0
# deposit     0
# dtype: int64

# %%
# Unknowns en categóricas
print("\nUNKNOWNS en categóricas:")
for col in ['poutcome']:
    n = (subset[col] == 'unknown').sum()
    print(f"  {col}: {n} ({n/len(subset)*100:.1f}%)")
# Out:
# UNKNOWNS en categóricas:
#   poutcome: 8326 (74.6%)

# %%
# Estadísticas numéricas
print("\nEstadísticas numéricas:")
subset[['day','duration','campaign','pdays','previous']].describe().round(2)
# Out:
# Estadísticas numéricas:
#             day  duration  campaign     pdays  previous
# count  11162.00  11162.00  11162.00  11162.00  11162.00
# mean      15.66    371.99      2.51     51.33      0.83
# std        8.42    347.13      2.72    108.76      2.29
# min        1.00      2.00      1.00     -1.00      0.00
# 25%        8.00    138.00      1.00     -1.00      0.00
# 50%       15.00    255.00      2.00     -1.00      0.00
# 75%       22.00    496.00      3.00     20.75      1.00
# max       31.00   3881.00     63.00    854.00     58.00

# %% [markdown]
# ## Área 1 — Tratamiento de valores nulos (NaN)

# %%
assert df[variables_fin].isnull().sum().sum() == 0, "Se encontraron NaN inesperados"
print("✓ Área 1 — Sin NaN en las variables asignadas. No se requiere acción.")
# Out:
# ✓ Área 1 — Sin NaN en las variables asignadas. No se requiere acción.

# %% [markdown]
# ## Área 2 — Duplicados

# %%
n_dup = df.duplicated().sum()
n_dup_id = df.index.duplicated().sum()
print(f"Filas duplicadas: {n_dup} | IDs duplicados: {n_dup_id}")

if n_dup > 0:
    df = df.drop_duplicates(keep='first').reset_index(drop=True)
    print(f"  → Eliminadas. Filas restantes: {len(df)}")
else:
    print("✓ Área 2 — Sin duplicados. No se requiere acción.")
# Out:
# Filas duplicadas: 0 | IDs duplicados: 0
# ✓ Área 2 — Sin duplicados. No se requiere acción.

# %% [markdown]
# ## Área 2 — Valores atípicos (Outliers)
#
# ### Variables numéricas: `duration`, `campaign`, `previous`
# **Método:** IQR para detección.
# **Sugerencia:** No se eliminan filas podria usarse tecnicas como la Winsorizacion. Es preferible a la eliminación cuando la proporción de outliers > 5%.
#
# ### Variable especial: `pdays`
# **Diagnóstico:** `pdays = -1` es una **codificación de negocio** (cliente no contactado previamente), no un outlier.
# Se separa en:
# - `pdays = -1` → `NaN` (para análisis estadístico correcto de días entre contactos)
# - Nueva variable binaria `contactado_campania_previa` (0/1)
# **Justificación:** Tratar -1 como valor numérico contaminaría media y desviación estándar de `pdays`.

# %%
# --- Winsorizing P99 para duration, campaign, previous ---
for col in ['duration', 'campaign', 'previous']:
    p99 = df[col].quantile(0.99)
    antes = df[col].max()
    df[col] = df[col].clip(upper=p99)
    print(f"{col}: max antes={antes:.0f} → cap P99={p99:.0f}")
# Out:
# duration: max antes=3881 → cap P99=1577
# campaign: max antes=63 → cap P99=13
# previous: max antes=58 → cap P99=10

# %%
# --- Tratamiento de pdays = -1 ---
df['contactado_campania_previa'] = (df['pdays'] != -1).astype(int)
df['pdays'] = df['pdays'].replace(-1, np.nan)

# %%
print(f"\npdays: {(df['pdays'].isna()).sum()} NaN (no contactados previamente)")
print(f"contactado_campania_previa: {df['contactado_campania_previa'].value_counts().to_dict()}")
# Out:
# pdays: 8324 NaN (no contactados previamente)
# contactado_campania_previa: {0: 8324, 1: 2838}

# %% [markdown]
# ## Área 3 — Estandarización de formatos
#
# ### `month` → Categorical ordenado
# **Decisión:** Convertir a `pd.Categorical` con orden cronológico natural.
# **Justificación:** `month` es una variable **ordinal** (tiene orden lógico: ene < feb < ... < dic).
# Las buenas prácticas indican que variables ordinales no deben tratarse como nominales ni reordenarse por frecuencia.
#
# ### `poutcome` → Renombrar `unknown` a `sin_campania_previa`
# **Decisión:** No convertir a NaN. El `unknown` tiene significado de negocio documentado.
# **Justificación:** El 74.1% de `poutcome='unknown'` coincide con `pdays=-1` (cliente sin campaña previa).
# Convertirlo a NaN e imputarlo generaría información falsa. Es una categoría válida.
#
# ### `deposit` → Estandarizar strings
# **Decisión:** Strip + lowercase para asegurar consistencia.
#
# ### `day` → Verificar rango válido
# **Decisión:** Solo verificación (rango 1-31). No requiere transformación.

# %%
# month → Categorical ordenadocon orden cronológico natural
orden_meses = ['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec']
df['month'] = pd.Categorical(
    df['month'].str.strip().str.lower(),
    categories=orden_meses,
    ordered=True
)

# %%
# poutcome → renombrar unknown (significado de negocio)
df['poutcome'] = df['poutcome'].str.strip().str.lower().replace('unknown', 'sin_campania_previa')

# %%
# deposit → estandarizar string
df['deposit'] = df['deposit'].str.strip().str.lower()

# %%
# day → verificación de rango
assert df['day'].between(1, 31).all(), "Valores de day fuera de rango válido"

# %%
print("Distribución month:", df['month'].value_counts().sort_index().to_dict())
print("\nDistribución poutcome:", df['poutcome'].value_counts().to_dict())
print("\nDistribución deposit:", df['deposit'].value_counts().to_dict())
print("\n✓ Área 4 — Estandarización completa.")
# Out:
# Distribución month: {'jan': 344, 'feb': 776, 'mar': 276, 'apr': 923, 'may': 2824, 'jun': 1222, 'jul': 1514, 'aug': 1519, 'sep': 319, 'oct': 392, 'nov': 943, 'dec': 110}
#
# Distribución poutcome: {'sin_campania_previa': 8326, 'failure': 1228, 'success': 1071, 'other': 537}
#
# Distribución deposit: {'no': 5873, 'yes': 5289}
#
# ✓ Área 4 — Estandarización completa.

# %% [markdown]
# ## Área 5 — Corrección de tipos de dato
#
# Según la documentación oficial del dataset UCI Bank Marketing, solo se modifico `month`, `pdays`
# `pdays` pasó de `int64` a `float64` por efecto de `np.nan`.

# %%
print("Tipos de dato post-limpieza:")
cols_check = variables_fin + ['contactado_campania_previa']
print(df[cols_check].dtypes)

# Asserts de tipos esperados
assert df['day'].dtype == 'int64'
assert df['duration'].dtype in ['int64', 'float64']
assert df['campaign'].dtype in ['int64', 'float64']
assert df['previous'].dtype in ['int64', 'float64']
assert str(df['month'].dtype) == 'category'
assert df['pdays'].dtype == 'float64'
assert df['deposit'].dtype == 'string'
assert df['poutcome'].dtype == 'string'

print("\n✓ Área 5 — Tipos de dato son corregidos - fase de limpieza.")
# Out:
# Tipos de dato post-limpieza:
# day                                    int64
# month                               category
# duration                             float64
# campaign                               int64
# pdays                                float64
# previous                               int64
# poutcome                      string[python]
# deposit                       string[python]
# contactado_campania_previa             int64
# dtype: object
#
# ✓ Área 5 — Tipos de dato son corregidos - fase de limpieza.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         11162 non-null  int64
#  1   job                         11162 non-null  string
#  2   marital                     11162 non-null  string
#  3   education                   11162 non-null  string
#  4   default                     11162 non-null  string
#  5   balance                     11162 non-null  int64
#  6   housing                     11162 non-null  string
#  7   loan                        11162 non-null  string
#  8   contact                     11162 non-null  string
#  9   day                         11162 non-null  int64
#  10  month                       11162 non-null  category
#  11  duration                    11162 non-null  float64
#  12  campaign                    11162 non-null  int64
#  13  pdays                       2838 non-null   float64
#  14  previous                    11162 non-null  int64
#  15  poutcome                    11162 non-null  string
#  16  deposit                     11162 non-null  string
#  17  contactado_campania_previa  11162 non-null  int64
# dtypes: category(1), float64(2), int64(6), string(9)
# memory usage: 1.5 MB

# %%
df.head(10)
# Out:
#    age             job   marital  education default  balance housing loan  \
# 0   59  administration   married  secondary      no     2343     yes   no
# 1   56  administration   married  secondary      no       45      no   no
# 2   41      technician   married  secondary      no     1270     yes   no
# 3   55        services   married  secondary      no     2476     yes   no
# 4   54  administration   married   tertiary      no      184      no   no
# 5   42      management    single   tertiary      no        0     yes  yes
# 6   56      management   married   tertiary      no      830     yes  yes
# 7   60         retired  divorced  secondary      no      545     yes   no
# 8   37      technician   married  secondary      no        1     yes   no
# 9   28        services    single  secondary      no     5090     yes   no
#
#    contact  day month  duration  campaign  pdays  previous  \
# 0  unknown    5   may    1042.0         1    NaN         0
# 1  unknown    5   may    1467.0         1    NaN         0
# 2  unknown    5   may    1389.0         1    NaN         0
# 3  unknown    5   may     579.0         1    NaN         0
# 4  unknown    5   may     673.0         2    NaN         0
# 5  unknown    5   may     562.0         2    NaN         0
# 6  unknown    6   may    1201.0         1    NaN         0
# 7  unknown    6   may    1030.0         1    NaN         0
# 8  unknown    6   may     608.0         1    NaN         0
# 9  unknown    6   may    1297.0         3    NaN         0
#
#               poutcome deposit  contactado_campania_previa
# 0  sin_campania_previa     yes                           0
# 1  sin_campania_previa     yes                           0
# 2  sin_campania_previa     yes                           0
# 3  sin_campania_previa     yes                           0
# 4  sin_campania_previa     yes                           0
# 5  sin_campania_previa     yes                           0
# 6  sin_campania_previa     yes                           0
# 7  sin_campania_previa     yes                           0
# 8  sin_campania_previa     yes                           0
# 9  sin_campania_previa     yes                           0

# %%
df.to_parquet('../../Data/df_limpiado_260504.parquet')
