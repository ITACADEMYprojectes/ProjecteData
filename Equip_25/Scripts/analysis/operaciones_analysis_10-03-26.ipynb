# %% [markdown]
# ## Librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import sys
from pathlib import Path

# Añadir la carpeta Scripts al path
ROOT = Path.cwd().parent  # asumiendo que cwd = Scripts/analysis
sys.path.append(str(ROOT))

from utils import guardar_pickle

# %% [markdown]
# ## Carga datos clean

# %%
BASE_DIR = None
for parent in [Path.cwd()] + list(Path.cwd().parents):
    if (parent / "Data").exists() and (parent / "Scripts").exists():
        BASE_DIR = parent
        break

if BASE_DIR is None:
    raise FileNotFoundError("No se pudo detectar la raíz del proyecto")

DATA_PATH = BASE_DIR / "Data" / "raw_data.csv"
df = pd.read_csv(DATA_PATH)
df['id'] = range(1, len(df)+1)

# %% [markdown]
# ## Análisis / visualizaciones

# %%
df_opt = df[['minimum_nights', 'maximum_nights', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'is_instant_bookable']]
df_opt
# Out:
#       minimum_nights  maximum_nights has_availability  availability_30  \
# 0                  3             365        VERDADERO                7
# 1                  4              40        VERDADERO                0
# 2                  2             120        VERDADERO               26
# 3                  2             730        VERDADERO                9
# 4                  1             180        VERDADERO                0
# ...              ...             ...              ...              ...
# 6996               7            1125        VERDADERO               26
# 6997               1            1125        VERDADERO               24
# 6998               1            1125        VERDADERO                0
# 6999               2              31        VERDADERO                2
# 7000               2              31        VERDADERO               23
#
#       availability_60  availability_90  availability_365 is_instant_bookable
# ...

# %% [markdown]
# ## Resultados / archivos generados
