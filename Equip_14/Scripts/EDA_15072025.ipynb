# %%
import pandas as pd

df_rrhh = pd.read_csv('/Users/gemmaseguesmajos/Downloads/DF-RRHH_15072025.csv', sep=',', encoding='utf-8')

df_rrhh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110 entries, 0 to 1109
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       1110 non-null   int64
#  1   Reason_absence           1110 non-null   int64
#  2   Month_absence            1110 non-null   int64
#  3   Day_week                 1110 non-null   int64
#  4   Seasons                  1110 non-null   int64
#  5   Transportation_expense   1110 non-null   int64
#  6   Distance_Residence_Work  1110 non-null   int64
#  7   Service_time             1110 non-null   int64
#  8   Age                      1110 non-null   int64
#  9   Work_load_Average_day    1110 non-null   object
#  10  Hit_target               1110 non-null   int64
#  11  Disciplinary_failure     1110 non-null   int64
#  12  Education                1110 non-null   int64
#  13  Son                      1110 non-null   int64
#  14  Social_drinker           1110 non-null   int64
#  15  Social_smoker            1110 non-null   int64
#  16  Pet                      1110 non-null   int64
#  17  Weight                   1110 non-null   int64
#  18  Height                   1110 non-null   int64
#  19  Body_mass_index          1110 non-null   int64
#  20  Absenteeism_hours        1110 non-null   int64
# dtypes: int64(20), object(1)
# memory usage: 182.2+ KB

# %%
df_rrhh.isnull().sum()
# Out:
# ID                         0
# Reason_absence             0
# Month_absence              0
# Day_week                   0
# Seasons                    0
# Transportation_expense     0
# Distance_Residence_Work    0
# Service_time               0
# Age                        0
# Work_load_Average_day      0
# Hit_target                 0
# Disciplinary_failure       0
# Education                  0
# Son                        0
# Social_drinker             0
# Social_smoker              0
# Pet                        0
# Weight                     0
# Height                     0
# Body_mass_index            0
# Absenteeism_hours          0
# dtype: int64

# %%
df_rrhh = df_rrhh.drop_duplicates()
df_rrhh = df_rrhh.sort_values(by='ID').reset_index(drop=True)
df_rrhh
# Out:
#        ID  Reason_absence  Month_absence  Day_week  Seasons  \
# 0       1              22              3         2        2
# 1       1              25             12         5        4
# 2       1              26             10         2        4
# 3       1               7              4         6        3
# 4       1              25             11         5        4
# ...   ...             ...            ...       ...      ...
# 1051  382              23              9         2        1
# 1052  383              22              3         3        2
# 1053  384               5              7         6        1
# 1054  385              27              2         5        2
# 1055  386              23              4         3        3
#
#       Transportation_expense  Distance_Residence_Work  Service_time  Age  \
# 0                        235                       11            14   37
# 1                        235                       11            14   37
# 2                        235                       11            14   37
# 3                        235                       11            14   37
# 4                        235                       11            14   37
# ...                      ...                      ...           ...  ...
# 1051                     118                       10            10   37
# 1052                     378                       49            11   36
# 1053                     118                       10            10   37
# 1054                     179                       51            18   38
# 1055                     361                       52             3   28
#
#      Work_load_Average_day  ...  Disciplinary_failure  Education  Son  \
# 0                  244,387  ...                     0          3    1
# 1                  236,629  ...                     0          3    1
# 2                  265,017  ...                     0          3    1
# 3                  326,452  ...                     0          3    1
# 4                  284,031  ...                     0          3    1
# ...                    ...  ...                   ...        ...  ...
# 1051               241,476  ...                     0          1    0
# 1052               244,387  ...                     0          1    2
# 1053               275,312  ...                     0          1    0
# 1054               264,249  ...                     0          1    0
# 1055               246,288  ...                     0          1    1
#
#       Social_drinker  Social_smoker  Pet  Weight  Height  Body_mass_index  \
# 0                  0              0    1      88     172               29
# 1                  0              0    1      88     172               29
# 2                  0              0    1      88     172               29
# 3                  0              0    1      88     172               29
# 4                  0              0    1      88     172               29
# ...              ...            ...  ...     ...     ...              ...
# 1051               0              0    0      83     172               28
# 1052               0              1    4      65     174               21
# 1053               0              0    0      83     172               28
# 1054               1              0    0      89     170               31
# 1055               1              0    4      80     172               27
#
#       Absenteeism_hours
# 0                     8
# 1                     2
# 2                     4
# 3                     3
# 4                     2
# ...                 ...
# 1051                  4
# 1052                  8
# 1053                  8
# 1054                  3
# 1055                  2
#
# [1056 rows x 21 columns]

# %%
df_rrhh['ID'] = df_rrhh['ID'].astype(str).str.strip()
df_rrhh['Reason_absence'] = df_rrhh['Reason_absence'].astype(str).str.strip()
df_rrhh['Work_load_Average_day'] = df_rrhh['Work_load_Average_day'].astype(str).str.replace(',', '.', regex=False).astype(float)
df_rrhh['Education'] = df_rrhh['Education'].astype(str).str.strip()
df_rrhh['Social_drinker'] = df_rrhh['Social_drinker'].astype(int)
df_rrhh['Social_smoker'] = df_rrhh['Social_smoker'].astype(int)
df_rrhh['Disciplinary_failure'] = df_rrhh['Disciplinary_failure'].astype(int)
df_rrhh['Son'] = df_rrhh['Son'].astype(int)
df_rrhh['Pet'] = df_rrhh['Pet'].astype(int)

df_rrhh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056 entries, 0 to 1055
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       1056 non-null   object
#  1   Reason_absence           1056 non-null   object
#  2   Month_absence            1056 non-null   int64
#  3   Day_week                 1056 non-null   int64
#  4   Seasons                  1056 non-null   int64
#  5   Transportation_expense   1056 non-null   int64
#  6   Distance_Residence_Work  1056 non-null   int64
#  7   Service_time             1056 non-null   int64
#  8   Age                      1056 non-null   int64
#  9   Work_load_Average_day    1056 non-null   float64
#  10  Hit_target               1056 non-null   int64
#  11  Disciplinary_failure     1056 non-null   int64
#  12  Education                1056 non-null   object
#  13  Son                      1056 non-null   int64
#  14  Social_drinker           1056 non-null   int64
#  15  Social_smoker            1056 non-null   int64
#  16  Pet                      1056 non-null   int64
#  17  Weight                   1056 non-null   int64
#  18  Height                   1056 non-null   int64
#  19  Body_mass_index          1056 non-null   int64
#  20  Absenteeism_hours        1056 non-null   int64
# dtypes: float64(1), int64(17), object(3)
# memory usage: 173.4+ KB

# %%
df_rrhh["Disciplinary_failure"] = df_rrhh["Disciplinary_failure"].astype(bool)
df_rrhh["Social_drinker"] = df_rrhh["Social_drinker"].astype(bool)
df_rrhh["Social_smoker"] = df_rrhh["Social_smoker"].astype(bool)

df_rrhh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056 entries, 0 to 1055
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       1056 non-null   object
#  1   Reason_absence           1056 non-null   object
#  2   Month_absence            1056 non-null   int64
#  3   Day_week                 1056 non-null   int64
#  4   Seasons                  1056 non-null   int64
#  5   Transportation_expense   1056 non-null   int64
#  6   Distance_Residence_Work  1056 non-null   int64
#  7   Service_time             1056 non-null   int64
#  8   Age                      1056 non-null   int64
#  9   Work_load_Average_day    1056 non-null   float64
#  10  Hit_target               1056 non-null   int64
#  11  Disciplinary_failure     1056 non-null   bool
#  12  Education                1056 non-null   object
#  13  Son                      1056 non-null   int64
#  14  Social_drinker           1056 non-null   bool
#  15  Social_smoker            1056 non-null   bool
#  16  Pet                      1056 non-null   int64
#  17  Weight                   1056 non-null   int64
#  18  Height                   1056 non-null   int64
#  19  Body_mass_index          1056 non-null   int64
#  20  Absenteeism_hours        1056 non-null   int64
# dtypes: bool(3), float64(1), int64(14), object(3)
# memory usage: 151.7+ KB

# %%
df_rrhh['Month_absence'].unique()
df_rrhh['Day_week'].unique()
# Out:
# array([2, 5, 6, 3, 4])

# %%
season_dict = {
    1: 'Estiu',
    2: 'Hivern',
    3: 'Primavera',
    4: 'Tardor'
}

df_rrhh['Seasons'] = df_rrhh['Seasons'].map(season_dict)

# %%
df_rrhh
# Out:
#        ID Reason_absence  Month_absence  Day_week    Seasons  \
# 0       1             22              3         2     Hivern
# 1       1             25             12         5     Tardor
# 2       1             26             10         2     Tardor
# 3       1              7              4         6  Primavera
# 4       1             25             11         5     Tardor
# ...   ...            ...            ...       ...        ...
# 1051  382             23              9         2      Estiu
# 1052  383             22              3         3     Hivern
# 1053  384              5              7         6      Estiu
# 1054  385             27              2         5     Hivern
# 1055  386             23              4         3  Primavera
#
#       Transportation_expense  Distance_Residence_Work  Service_time  Age  \
# 0                        235                       11            14   37
# 1                        235                       11            14   37
# 2                        235                       11            14   37
# 3                        235                       11            14   37
# 4                        235                       11            14   37
# ...                      ...                      ...           ...  ...
# 1051                     118                       10            10   37
# 1052                     378                       49            11   36
# 1053                     118                       10            10   37
# 1054                     179                       51            18   38
# 1055                     361                       52             3   28
#
#       Work_load_Average_day  ...  Disciplinary_failure  Education Son  \
# 0                   244.387  ...                 False          3   1
# 1                   236.629  ...                 False          3   1
# 2                   265.017  ...                 False          3   1
# 3                   326.452  ...                 False          3   1
# 4                   284.031  ...                 False          3   1
# ...                     ...  ...                   ...        ...  ..
# 1051                241.476  ...                 False          1   0
# 1052                244.387  ...                 False          1   2
# 1053                275.312  ...                 False          1   0
# 1054                264.249  ...                 False          1   0
# 1055                246.288  ...                 False          1   1
#
#       Social_drinker  Social_smoker  Pet  Weight  Height  Body_mass_index  \
# 0              False          False    1      88     172               29
# 1              False          False    1      88     172               29
# 2              False          False    1      88     172               29
# 3              False          False    1      88     172               29
# 4              False          False    1      88     172               29
# ...              ...            ...  ...     ...     ...              ...
# 1051           False          False    0      83     172               28
# 1052           False           True    4      65     174               21
# 1053           False          False    0      83     172               28
# 1054            True          False    0      89     170               31
# 1055            True          False    4      80     172               27
#
#       Absenteeism_hours
# 0                     8
# 1                     2
# 2                     4
# 3                     3
# 4                     2
# ...                 ...
# 1051                  4
# 1052                  8
# 1053                  8
# 1054                  3
# 1055                  2
#
# [1056 rows x 21 columns]

# %%
month_dict = {
    1: 'Gen',
    2: 'Feb',
    3: 'Mar',
    4: 'Abr',
    5: 'Mai',
    6: 'Jun',
    7: 'Jul',
    8: 'Ago',
    9: 'Set',
    10: 'Oct',
    11: 'Nov',
    12: 'Des'
}

df_rrhh['Month_absence'] = df_rrhh['Month_absence'].map(month_dict)

df_rrhh
# Out:
#        ID Reason_absence Month_absence  Day_week    Seasons  \
# 0       1             22           Mar         2     Hivern
# 1       1             25           Des         5     Tardor
# 2       1             26           Oct         2     Tardor
# 3       1              7           Abr         6  Primavera
# 4       1             25           Nov         5     Tardor
# ...   ...            ...           ...       ...        ...
# 1051  382             23           Set         2      Estiu
# 1052  383             22           Mar         3     Hivern
# 1053  384              5           Jul         6      Estiu
# 1054  385             27           Feb         5     Hivern
# 1055  386             23           Abr         3  Primavera
#
#       Transportation_expense  Distance_Residence_Work  Service_time  Age  \
# 0                        235                       11            14   37
# 1                        235                       11            14   37
# 2                        235                       11            14   37
# 3                        235                       11            14   37
# 4                        235                       11            14   37
# ...                      ...                      ...           ...  ...
# 1051                     118                       10            10   37
# 1052                     378                       49            11   36
# 1053                     118                       10            10   37
# 1054                     179                       51            18   38
# 1055                     361                       52             3   28
#
#       Work_load_Average_day  ...  Disciplinary_failure  Education Son  \
# 0                   244.387  ...                 False          3   1
# 1                   236.629  ...                 False          3   1
# 2                   265.017  ...                 False          3   1
# 3                   326.452  ...                 False          3   1
# 4                   284.031  ...                 False          3   1
# ...                     ...  ...                   ...        ...  ..
# 1051                241.476  ...                 False          1   0
# 1052                244.387  ...                 False          1   2
# 1053                275.312  ...                 False          1   0
# 1054                264.249  ...                 False          1   0
# 1055                246.288  ...                 False          1   1
#
#       Social_drinker  Social_smoker  Pet  Weight  Height  Body_mass_index  \
# 0              False          False    1      88     172               29
# 1              False          False    1      88     172               29
# 2              False          False    1      88     172               29
# 3              False          False    1      88     172               29
# 4              False          False    1      88     172               29
# ...              ...            ...  ...     ...     ...              ...
# 1051           False          False    0      83     172               28
# 1052           False           True    4      65     174               21
# 1053           False          False    0      83     172               28
# 1054            True          False    0      89     170               31
# 1055            True          False    4      80     172               27
#
#       Absenteeism_hours
# 0                     8
# 1                     2
# 2                     4
# 3                     3
# 4                     2
# ...                 ...
# 1051                  4
# 1052                  8
# 1053                  8
# 1054                  3
# 1055                  2
#
# [1056 rows x 21 columns]

# %%
day_dict = {
    2: 'Dll',
    3: 'Dm',
    4: 'Dc',
    5: 'Dj',
    6: 'Dv'
    }

df_rrhh['Day_week'] = df_rrhh['Day_week'].map(day_dict)

df_rrhh
# Out:
#        ID Reason_absence Month_absence Day_week    Seasons  \
# 0       1             22           Mar      Dll     Hivern
# 1       1             25           Des       Dj     Tardor
# 2       1             26           Oct      Dll     Tardor
# 3       1              7           Abr       Dv  Primavera
# 4       1             25           Nov       Dj     Tardor
# ...   ...            ...           ...      ...        ...
# 1051  382             23           Set      Dll      Estiu
# 1052  383             22           Mar       Dm     Hivern
# 1053  384              5           Jul       Dv      Estiu
# 1054  385             27           Feb       Dj     Hivern
# 1055  386             23           Abr       Dm  Primavera
#
#       Transportation_expense  Distance_Residence_Work  Service_time  Age  \
# 0                        235                       11            14   37
# 1                        235                       11            14   37
# 2                        235                       11            14   37
# 3                        235                       11            14   37
# 4                        235                       11            14   37
# ...                      ...                      ...           ...  ...
# 1051                     118                       10            10   37
# 1052                     378                       49            11   36
# 1053                     118                       10            10   37
# 1054                     179                       51            18   38
# 1055                     361                       52             3   28
#
#       Work_load_Average_day  ...  Disciplinary_failure  Education Son  \
# 0                   244.387  ...                 False          3   1
# 1                   236.629  ...                 False          3   1
# 2                   265.017  ...                 False          3   1
# 3                   326.452  ...                 False          3   1
# 4                   284.031  ...                 False          3   1
# ...                     ...  ...                   ...        ...  ..
# 1051                241.476  ...                 False          1   0
# 1052                244.387  ...                 False          1   2
# 1053                275.312  ...                 False          1   0
# 1054                264.249  ...                 False          1   0
# 1055                246.288  ...                 False          1   1
#
#       Social_drinker  Social_smoker  Pet  Weight  Height  Body_mass_index  \
# 0              False          False    1      88     172               29
# 1              False          False    1      88     172               29
# 2              False          False    1      88     172               29
# 3              False          False    1      88     172               29
# 4              False          False    1      88     172               29
# ...              ...            ...  ...     ...     ...              ...
# 1051           False          False    0      83     172               28
# 1052           False           True    4      65     174               21
# 1053           False          False    0      83     172               28
# 1054            True          False    0      89     170               31
# 1055            True          False    4      80     172               27
#
#       Absenteeism_hours
# 0                     8
# 1                     2
# 2                     4
# 3                     3
# 4                     2
# ...                 ...
# 1051                  4
# 1052                  8
# 1053                  8
# 1054                  3
# 1055                  2
#
# [1056 rows x 21 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
sns.heatmap(df_rrhh.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matriu de correlació")
plt.show()
