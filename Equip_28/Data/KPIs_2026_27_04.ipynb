# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df_crudo = pd.read_csv("data_cleaning_2026_27_04.csv")

# %%
df_crudo.columns
# Out:
# Index(['id', 'motivo_ausencia', 'mes_ausencia', 'dia_semana', 'estaciones',
#        'gasto_transporte', 'distancia_casa_trabajo', 'tiempo_servicio', 'edad',
#        'carga_trabajo_diaria', 'cumplimiento_objetivo', 'falta_disciplinaria',
#        'educacion', 'hijos', 'bebedor_social', 'fumador_social', 'mascota',
#        'peso', 'estatura', 'indice_masa_corporal', 'horas_ausentismo',
#        'indicador_enfermedad', 'motivo_ausencia_mapeado',
#        'mes_ausencia_mapeado', 'educacion_mapeada'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 806 entries, 0 to 805
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       806 non-null    int64
#  1   motivo_ausencia          806 non-null    int64
#  2   mes_ausencia             802 non-null    float64
#  3   dia_semana               806 non-null    object
#  4   estaciones               806 non-null    object
#  5   gasto_transporte         806 non-null    int64
#  6   distancia_casa_trabajo   806 non-null    int64
#  7   tiempo_servicio          806 non-null    int64
#  8   edad                     806 non-null    int64
#  9   carga_trabajo_diaria     806 non-null    float64
#  10  cumplimiento_objetivo    806 non-null    int64
#  11  falta_disciplinaria      806 non-null    int64
#  12  educacion                806 non-null    int64
#  13  hijos                    806 non-null    int64
#  14  bebedor_social           806 non-null    int64
#  15  fumador_social           806 non-null    int64
#  16  mascota                  806 non-null    int64
#  17  peso                     806 non-null    int64
#  18  estatura                 806 non-null    int64
#  19  indice_masa_corporal     806 non-null    int64
#  20  horas_ausentismo         806 non-null    int64
#  21  indicador_enfermedad     758 non-null    object
#  22  motivo_ausencia_mapeado  758 non-null    object
#  23  mes_ausencia_mapeado     802 non-null    object
#  24  educacion_mapeada        806 non-null    object
# dtypes: float64(2), int64(17), object(6)
# memory usage: 157.6+ KB

# %% [markdown]
# ## % empleados ausentes

# %%
total_empleados = df_crudo['id'].nunique()
empleados_con_ausencia = df_crudo.loc[df_crudo['horas_ausentismo'] > 0, 'id'].nunique()
porcentaje_ausentes_crudo = (empleados_con_ausencia / total_empleados) * 100
print(f"porcentaje_ausentes: {porcentaje_ausentes_crudo:.2f}%")
# Out:
# porcentaje_ausentes: 94.12%

# %% [markdown]
# ## Mes pico de carga por ausencia

# %%
suma_por_mes = df.groupby('mes_ausencia_mapeado')['horas_ausentismo'].sum()
max_val = suma_por_mes.max()
mesi_pico = suma_por_mes[suma_por_mes == max_val].index.tolist()
print("Mesi con carico massimo:", mesi_pico)
print("Ore totali nel/nei mese/i pico:", float(max_val))
# Out:
# Mesi con carico massimo: ['Marzo']
# Ore totali nel/nei mese/i pico: 923.0

# %% [markdown]
# ## Motivo modal de absenteismo laboral

# %%
freq = df['motivo_ausencia_mapeado'].value_counts(dropna=True)

if freq.empty:
    motivo_modal = []
    freq_motivo_modal = 0
else:
    max_freq = freq.max()
    motivo_modal = freq[freq == max_freq].index.tolist()
    freq_motivo_modal = int(max_freq)

print("Motivo modal:", motivo_modal)
print("Frequenza del motivo modal:", freq_motivo_modal)
# Out:
# Motivo modal: ['Consulta Médica']
# Frequenza del motivo modal: 161

# %% [markdown]
# ## Index eficiencia relativa por carga laboral

# %%
#(Suma de Hit target) / (Suma de Work load Average per day)

suma_hit_target = df['cumplimiento_objetivo'].sum()
suma_work_load = df['carga_trabajo_diaria'].sum()

if suma_work_load != 0:
    kpi = suma_hit_target / suma_work_load
    print(f"KPI: {kpi:.2f}")
else:
    print("KPI: No disponible (Work load average es zero)")
# Out:
# KPI: 0.35
