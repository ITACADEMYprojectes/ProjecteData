# %% [markdown]
# # Análisis de perfil y desempeño 08/06/2026

# %% [markdown]
# Influeixen l’antiguitat, la càrrega laboral diària o la distància fins al lloc de treball en el rendiment dels nostres col·laboradors?
# Podem identificar perfils amb major risc de baix rendiment i fer ajustaments en l’organització per potenciar els resultats?
#
# Mensaje de Verónica:
# En vuestro caso hay que dosificar más el esfuerzo y la complejidad. He contado 6 técnicas creo para una pregunta que a nivel general es sencilla.
#
# Recomiendo ir por descriptivo + una técnica más (o bien RLM si el score lo trabajan como variable continua o regresión logística multinomial si la trabajan como categórica). En vuestro caso, diría que el "error" está en intentar deducir de cada parte de la pregunta una técnica de análisis.

# %% [markdown]
# Queda por hacer:
# - Gráficos "bonitos" distribución Score rendimiento (agrupado por ID)
# - Influencia (Noelia)
#     - Spearman
#     - RLM
# - Perfiles (Sabina)
#     - Definir los perfiles
#     - Descriptivos generales y de los perfiles
#     - Multinomial

# %% [markdown]
# # Librerías

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import date
import scipy.stats as stats
import numpy as np
import plotly.graph_objs as go
import seaborn as sns
from scipy.stats import spearmanr 
from scipy.stats import mannwhitneyu
import statsmodels.formula.api as smf
from matplotlib.lines import Line2D
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Funciones

# %%
def distr_hist(df: pd.DataFrame, column: str, bars: int) -> None:
    """
    Muestra un histograma para una columna del DataFrame.

    Parameters
    ----------
    df : pd.DataFrame
        DataFrame con los datos.
    column : str
        Columna a visualizar.
    bars : int
        Número de barras del histograma.
    """
    plt.hist(df[column], bins=bars)
    plt.title(f'Distribución de la variable {column}')
    plt.show()

# %%
def distr_value(df: pd.DataFrame, column: str) -> None:
    """
    Muestra la distribución porcentual y los valores únicos de una columna.

    Parameters
    ----------
    df : pd.DataFrame
        DataFrame con los datos.
    column : str
        Columna a analizar.
    """
    value_count = df[column].value_counts(normalize=True)*100
    print(f'Value counts: {value_count}')
    val_unique = df[column].unique()
    print(f'----\nValores únicos:{val_unique}')
    
    print('----\nGráfico distribución valores únicos:')
    (df[column]
    .value_counts(normalize=True)
    .mul(100)
    .plot(kind='bar'))

    plt.ylabel('Porcentaje (%)')
    plt.xlabel('Hit_target')
    plt.title('Distribución de Hit_target')
    plt.show()

# %%
def distr_boxplot(df: pd.DataFrame, column: str) -> None:
    """
    Muestra un boxplot para una columna del DataFrame.

    Parameters
    ----------
    df : pd.DataFrame
        DataFrame con los datos.
    column : str
        Columna a visualizar.
    """
    plt.boxplot(df[column])
    plt.title(f'Boxplot de la variable {column}')
    plt.show()

# %%
def outliers_column(df: pd.DataFrame, column: str) -> pd.DataFrame:
    """
    Devuelve las filas con valores atípicos en una columna usando el método IQR.

    Parameters
    ----------
    df : pd.DataFrame
        DataFrame con los datos.
    column : str
        Columna numérica a analizar.
    """
    col = df[column]

    Q1 = col.quantile(0.25)
    Q3 = col.quantile(0.75)
    IQR = Q3 - Q1

    limit_inferior = Q1 - 1.5 * IQR
    limit_superior = Q3 + 1.5 * IQR

    outliers = df[(col < limit_inferior) | (col > limit_superior)]
    
    return outliers

# %% [markdown]
# # Documento

# %%
df_RRHH = pd.read_csv('../../Data/clean/clean_data_08062026.csv')
df_RRHH
# Out:
#       ID  Reason_absence                                Reason_absence_name  \
# 0     14            11.0                                  Sistema digestivo
# 1     36            13.0                         Sistema musculoesquelético
# 2      9             6.0                                   Sistema nervioso
# 3     28             9.0                               Sistema circulatorio
# 4      9            12.0                           Piel y tejido subcutáneo
# ...   ..             ...                                                ...
# 1104  22             1.0            Enfermedades infecciosas y parasitarias
# 1105  26            19.0  Lesiones, intoxicaciones y consecuencias externas
# 1106  34            19.0  Lesiones, intoxicaciones y consecuencias externas
# 1107  20            19.0  Lesiones, intoxicaciones y consecuencias externas
# 1108  14            10.0                               Sistema respiratorio
#
#       Month_absence Month_absence_name  Day_week Day_week_name  Seasons  \
# 0               5.0               Mayo         2         Lunes        2
# 1              10.0            Octubre         4     Miércoles        4
# 2               1.0              Enero         3        Martes        1
# 3               1.0              Enero         3        Martes        1
# 4               9.0         Septiembre         3        Martes        3
# ...             ...                ...       ...           ...      ...
# 1104            4.0              Abril         4     Miércoles        2
# 1105           11.0          Noviembre         6       Viernes        4
# 1106            6.0              Junio         3        Martes        2
# 1107           10.0            Octubre         6       Viernes        4
# 1108           11.0          Noviembre         2         Lunes        4
#
#      Seasons_name  Transportation_expense  ...  Son  Social_drinker  \
# 0       Primavera                     155  ...    2               1
# 1           Otoño                     118  ...    1               1
# 2        Invierno                     228  ...    2               0
# 3        Invierno                     225  ...    1               0
# 4          Verano                     228  ...    2               0
# ...           ...                     ...  ...  ...             ...
# 1104    Primavera                     179  ...    0               0
# 1105        Otoño                     300  ...    2               1
# 1106    Primavera                     118  ...    0               0
# 1107        Otoño                     260  ...    4               1
# 1108        Otoño                     155  ...    2               1
#
#       Social_smoker  Pet  Weight  Height  Body_mass_index BMI_calculated  \
# 0                 0    0      95     196               25           24.7
# 1                 0    0      98     178               31           30.9
# 2                 0    1      65     172               22           22.0
# 3                 0    2      69     169               24           24.2
# 4                 0    1      65     172               22           22.0
# ...             ...  ...     ...     ...              ...            ...
# 1104              0    0      56     171               19           19.2
# 1105              1    1      77     175               25           25.1
# 1106              0    0      83     172               28           28.1
# 1107              0    0      65     168               23           23.0
# 1108              0    0      95     196               25           24.7
#
#       Absenteeism_hours  importacion
# 0                   120   2026-05-25
# 1                   120   2026-05-25
# 2                   120   2026-05-25
# 3                   112   2026-05-25
# 4                   112   2026-05-25
# ...                 ...          ...
# 1104                 64   2026-06-08
# 1105                 64   2026-06-08
# 1106                 56   2026-06-08
# 1107                 56   2026-06-08
# 1108                 48   2026-06-08
#
# [1109 rows x 28 columns]

# %%
df_RRHH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1109 entries, 0 to 1108
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       1109 non-null   int64
#  1   Reason_absence           1042 non-null   float64
#  2   Reason_absence_name      1042 non-null   object
#  3   Month_absence            1106 non-null   float64
#  4   Month_absence_name       1106 non-null   object
#  5   Day_week                 1109 non-null   int64
#  6   Day_week_name            1109 non-null   object
#  7   Seasons                  1109 non-null   int64
#  8   Seasons_name             1109 non-null   object
#  9   Transportation_expense   1109 non-null   int64
#  10  Distance_Residence_Work  1109 non-null   int64
#  11  Service_time             1109 non-null   int64
#  12  Age                      1109 non-null   int64
#  13  Work_load_Average_day    1109 non-null   float64
#  14  Hit_target               1109 non-null   int64
#  15  Disciplinary_failure     1109 non-null   int64
#  16  Education                1109 non-null   int64
#  17  Education_name           1109 non-null   object
#  18  Son                      1109 non-null   int64
#  19  Social_drinker           1109 non-null   int64
#  20  Social_smoker            1109 non-null   int64
#  21  Pet                      1109 non-null   int64
#  22  Weight                   1109 non-null   int64
#  23  Height                   1109 non-null   int64
#  24  Body_mass_index          1109 non-null   int64
#  25  BMI_calculated           1109 non-null   float64
#  26  Absenteeism_hours        1109 non-null   int64
#  27  importacion              1109 non-null   object
# dtypes: float64(4), int64(18), object(6)
# memory usage: 242.7+ KB

# %%
df_RRHH.shape
# Out:
# (1109, 28)

# %%
df_RRHH.describe().T
# Out:
#                           count        mean         std      min      25%  \
# ID                       1109.0   79.120830  106.751321    1.000   13.000
# Reason_absence           1042.0   20.215931    7.179088    1.000   13.000
# Month_absence            1106.0    6.472875    3.449400    1.000    4.000
# Day_week                 1109.0    3.904418    1.433819    2.000    3.000
# Seasons                  1109.0    2.516682    1.108281    1.000    2.000
# Transportation_expense   1109.0  221.312894   66.615474  118.000  179.000
# Distance_Residence_Work  1109.0   29.507665   14.804538    5.000   16.000
# Service_time             1109.0   12.655546    4.369696    1.000    9.000
# Age                      1109.0   36.647430    6.655875   27.000   31.000
# Work_load_Average_day    1109.0  270.145783   38.987515  205.917  241.476
# Hit_target               1109.0   94.636610    3.747027   81.000   93.000
# Disciplinary_failure     1109.0    0.057710    0.233299    0.000    0.000
# Education                1109.0    1.276826    0.654073    1.000    1.000
# Son                      1109.0    1.059513    1.105480    0.000    0.000
# Social_drinker           1109.0    0.568079    0.495567    0.000    0.000
# Social_smoker            1109.0    0.084761    0.278651    0.000    0.000
# Pet                      1109.0    0.759243    1.318679    0.000    0.000
# Weight                   1109.0   79.045987   12.770491   56.000   69.000
# Height                   1109.0  172.074842    6.024528  163.000  169.000
# Body_mass_index          1109.0   26.686204    4.245703   19.000   24.000
# BMI_calculated           1109.0   26.709197    4.218415   19.200   23.700
# Absenteeism_hours        1109.0    9.156898   19.688153    0.000    2.000
#
#                              50%      75%      max
# ID                        28.000  109.000  386.000
# Reason_absence            23.000   26.000   28.000
# Month_absence              7.000    9.000   12.000
# Day_week                   4.000    5.000    6.000
# Seasons                    3.000    4.000    4.000
# Transportation_expense   225.000  260.000  388.000
# Distance_Residence_Work   26.000   50.000   52.000
# Service_time              13.000   16.000   29.000
# Age                       37.000   40.000   58.000
# Work_load_Average_day    264.249  284.853  378.884
# Hit_target                95.000   97.000  100.000
# Disciplinary_failure       0.000    0.000    1.000
# Education                  1.000    1.000    4.000
# Son                        1.000    2.000    4.000
# Social_drinker             1.000    1.000    1.000
# Social_smoker              0.000    0.000    1.000
# Pet                        0.000    1.000    8.000
# Weight                    83.000   89.000  108.000
# Height                   170.000  172.000  196.000
# Body_mass_index           25.000   31.000   38.000
# BMI_calculated            25.100   30.800   38.000
# Absenteeism_hours          3.000    8.000  120.000

# %%
df_RRHH.columns
# Out:
# Index(['ID', 'Reason_absence', 'Reason_absence_name', 'Month_absence',
#        'Month_absence_name', 'Day_week', 'Day_week_name', 'Seasons',
#        'Seasons_name', 'Transportation_expense', 'Distance_Residence_Work',
#        'Service_time', 'Age', 'Work_load_Average_day', 'Hit_target',
#        'Disciplinary_failure', 'Education', 'Education_name', 'Son',
#        'Social_drinker', 'Social_smoker', 'Pet', 'Weight', 'Height',
#        'Body_mass_index', 'BMI_calculated', 'Absenteeism_hours',
#        'importacion'],
#       dtype='object')

# %% [markdown]
# Listas de columnas numéricas y categóricas separadas de todo el dataset (con 'ID')

# %%
num = ['ID','Transportation_expense', 'Distance_Residence_Work', 'Service_time',
       'Age', 'Work_load_Average_day', 'Hit_target','Pet', 'Son',
       'Weight', 'Height', 'Absenteeism_hours', 'BMI_calculated']

cat = ['ID','Reason_absence', 'Month_absence', 'Day_week',
       'Seasons', 'Disciplinary_failure', 'Education',
       'Social_drinker', 'Social_smoker']

# %% [markdown]
# ## Tamaño de muestra

# %%
df_RRHH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1109 entries, 0 to 1108
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       1109 non-null   int64
#  1   Reason_absence           1042 non-null   float64
#  2   Reason_absence_name      1042 non-null   object
#  3   Month_absence            1106 non-null   float64
#  4   Month_absence_name       1106 non-null   object
#  5   Day_week                 1109 non-null   int64
#  6   Day_week_name            1109 non-null   object
#  7   Seasons                  1109 non-null   int64
#  8   Seasons_name             1109 non-null   object
#  9   Transportation_expense   1109 non-null   int64
#  10  Distance_Residence_Work  1109 non-null   int64
#  11  Service_time             1109 non-null   int64
#  12  Age                      1109 non-null   int64
#  13  Work_load_Average_day    1109 non-null   float64
#  14  Hit_target               1109 non-null   int64
#  15  Disciplinary_failure     1109 non-null   int64
#  16  Education                1109 non-null   int64
#  17  Education_name           1109 non-null   object
#  18  Son                      1109 non-null   int64
#  19  Social_drinker           1109 non-null   int64
#  20  Social_smoker            1109 non-null   int64
#  21  Pet                      1109 non-null   int64
#  22  Weight                   1109 non-null   int64
#  23  Height                   1109 non-null   int64
#  24  Body_mass_index          1109 non-null   int64
#  25  BMI_calculated           1109 non-null   float64
#  26  Absenteeism_hours        1109 non-null   int64
#  27  importacion              1109 non-null   object
# dtypes: float64(4), int64(18), object(6)
# memory usage: 242.7+ KB

# %%
# Función para calcular la moda de variables categóricas/temporales
def moda(x):
    m = x.dropna().mode()
    return m.iloc[0] if len(m) > 0 else np.nan

df_emp = df_RRHH.groupby('ID').agg(
    # Variable dependiente agregada a nivel empleado
    Hit_target_median=('Hit_target', 'median'),
    Hit_target_mean=('Hit_target', 'mean'),

    # Número de solicitudes / registros de ausencia por empleado
    num_absences=('ID', 'size'),

    # Variables numéricas del empleado
    Age=('Age', 'first'),
    Service_time=('Service_time', 'first'),
    Distance_Residence_Work=('Distance_Residence_Work', 'first'),
    Transportation_expense=('Transportation_expense', 'first'),

    # Variables que pueden variar por registro
    Absenteeism_hours_total=('Absenteeism_hours', 'sum'),
    Absenteeism_hours_median=('Absenteeism_hours', 'median'),
    # Work_load_Average_day_median=('Work_load_Average_day', 'median'),

    # Variables categóricas/dummy del empleado
    Disciplinary_failure=('Disciplinary_failure', 'first'),
    Education=('Education', 'first'),
    Son=('Son', 'first'),
    Social_drinker=('Social_drinker', 'first'),
    Social_smoker=('Social_smoker', 'first'),
    Pet=('Pet', 'first'),

    # Variables temporales: valor más frecuente por empleado
    Month_absence_mode=('Month_absence', moda),
    Seasons_mode=('Seasons', moda)
).reset_index()

# %%
variables_grupo = [
    'Disciplinary_failure',
    'Education',
    'Son',
    'Social_drinker',
    'Social_smoker',
    'Pet'
]

for var in variables_grupo:
    #print(f"\n{var}")
    print(df_emp[var].value_counts(dropna=False))
    print(df_emp[var].value_counts(normalize=True, dropna=False) * 100)
# Out:
# Disciplinary_failure
# 0    360
# 1     26
# Name: count, dtype: int64
# Disciplinary_failure
# 0    93.264249
# 1     6.735751
# Name: proportion, dtype: float64
# Education
# 1    321
# 3     31
# 2     31
# 4      3
# Name: count, dtype: int64
# Education
# 1    83.160622
# 3     8.031088
# 2     8.031088
# 4     0.777202
# Name: proportion, dtype: float64
# Son
# 0    140
# 1    114
# 2    102
# 4     23
# 3      7
# Name: count, dtype: int64
# Son
# 0    36.269430
# 1    29.533679
# 2    26.424870
# 4     5.958549
# 3     1.813472
# Name: proportion, dtype: float64
# Social_drinker
# 1    218
# 0    168
# Name: count, dtype: int64
# Social_drinker
# 1    56.476684
# 0    43.523316
# Name: proportion, dtype: float64
# Social_smoker
# 0    340
# 1     46
# Name: count, dtype: int64
# Social_smoker
# 0    88.082902
# 1    11.917098
# Name: proportion, dtype: float64
# Pet
# 0    226
# 1     80
# 2     50
# 4     17
# 5      8
# 8      5
# Name: count, dtype: int64
# Pet
# 0    58.549223
# 1    20.725389
# 2    12.953368
# 4     4.404145
# 5     2.072539
# 8     1.295337
# Name: proportion, dtype: float64

# %% [markdown]
# # Pregunta de negocio

# %% [markdown]
# **Analista de Perfil i Desempeño Professional:**
# - Influeixen l’antiguitat, la càrrega laboral diària o la distància fins al lloc de treball en el rendiment dels nostres col·laboradors?
# - Podem identificar perfils amb major risc de baix rendiment i fer ajustaments en l’organització per potenciar els resultats?

# %% [markdown]
# - [KPIs para empresas de transporte: 10 indicadores clave](https://www.lextransport.es/kpis-para-empresas-de-transporte/)
# - [Descubre qué es el rendimiento laboral y su importancia](https://mx.indeed.com/orientacion-profesional/desarrollo-profesional/rendimiento-laboral)
#
# - [8 estrategias para aumentar el rendimiento de tu flota](https://www.eurowag.com/es/blog/8-estrategias-para-aumentar-el-rendimiento-de-tu-flota)

# %% [markdown]
# ## Crear score **Rendimiento**

# %% [markdown]
# ### Subset de las variables a estudiar
# Variables influencia:
# - Antigüedad (Service_time)
# - Carga Trabajo
# - Distancia al trabajo
#
# Variables score rendimiento:
# - Horas absentismo
# - Desempeño (Hit target)
# - Disciplinary failure
#
# Variables contexto:
# - ID
# - Mes (+ nombre)
# - fecha importacion

# %%
df_RRHH.columns
# Out:
# Index(['ID', 'Reason_absence', 'Reason_absence_name', 'Month_absence',
#        'Month_absence_name', 'Day_week', 'Day_week_name', 'Seasons',
#        'Seasons_name', 'Transportation_expense', 'Distance_Residence_Work',
#        'Service_time', 'Age', 'Work_load_Average_day', 'Hit_target',
#        'Disciplinary_failure', 'Education', 'Education_name', 'Son',
#        'Social_drinker', 'Social_smoker', 'Pet', 'Weight', 'Height',
#        'Body_mass_index', 'BMI_calculated', 'Absenteeism_hours',
#        'importacion'],
#       dtype='object')

# %%
var_subset = ['ID', 'Month_absence','Month_absence_name',
              'Distance_Residence_Work','Service_time', 'Work_load_Average_day',
              'Hit_target','Disciplinary_failure','Absenteeism_hours']

# %%
df_RRHH_subset = df_RRHH[var_subset].copy()
df_RRHH_subset
# Out:
#       ID  Month_absence Month_absence_name  Distance_Residence_Work  \
# 0     14            5.0               Mayo                       12
# 1     36           10.0            Octubre                       13
# 2      9            1.0              Enero                       14
# 3     28            1.0              Enero                       26
# 4      9            9.0         Septiembre                       14
# ...   ..            ...                ...                      ...
# 1104  22            4.0              Abril                       26
# 1105  26           11.0          Noviembre                       26
# 1106  34            6.0              Junio                       10
# 1107  20           10.0            Octubre                       50
# 1108  14           11.0          Noviembre                       12
#
#       Service_time  Work_load_Average_day  Hit_target  Disciplinary_failure  \
# 0               14                284.031          97                     0
# 1               18                239.409          98                     0
# 2               16                264.604          93                     0
# 3                9                230.290          92                     0
# 4               16                222.196          99                     0
# ...            ...                    ...         ...                   ...
# 1104             9                265.017          88                     0
# 1105            13                237.656          99                     0
# 1106            10                261.306          97                     0
# 1107            11                326.452          96                     0
# 1108            14                237.656          99                     0
#
#       Absenteeism_hours
# 0                   120
# 1                   120
# 2                   120
# 3                   112
# 4                   112
# ...                 ...
# 1104                 64
# 1105                 64
# 1106                 56
# 1107                 56
# 1108                 48
#
# [1109 rows x 9 columns]

# %%
df_RRHH_subset['ID'].nunique()
# Out:
# 386

# %% [markdown]
# ### Agrupación por ID y mes

# %%
df_grouped_ID_month = (
    df_RRHH_subset
    .groupby(['ID', 'Month_absence'], as_index=False, dropna=False)
    .agg({
        'Month_absence_name': 'first',
        'Distance_Residence_Work': 'first',
        'Service_time': 'first',
        'Work_load_Average_day': 'median',
        'Hit_target': 'first',
        'Disciplinary_failure': 'max',
        'Absenteeism_hours': 'sum',
    })
)

df_grouped_ID_month['Work_load_Average_day'] = df_grouped_ID_month['Work_load_Average_day'].round(3)

# %%
df_grouped_ID_month
# Out:
#       ID  Month_absence Month_absence_name  Distance_Residence_Work  \
# 0      1            1.0              Enero                       11
# 1      1            2.0            Febrero                       11
# 2      1            4.0              Abril                       11
# 3      1            5.0               Mayo                       11
# 4      1            6.0              Junio                       11
# ..   ...            ...                ...                      ...
# 582  382            1.0              Enero                       36
# 583  383            8.0             Agosto                       51
# 584  384            1.0              Enero                       36
# 585  385            8.0             Agosto                       27
# 586  386           12.0          Diciembre                       15
#
#      Service_time  Work_load_Average_day  Hit_target  Disciplinary_failure  \
# 0              14                252.079          97                     0
# 1              14                257.706          94                     0
# 2              14                265.017          88                     0
# 3              14                284.031          97                     0
# 4              14                236.629          97                     0
# ..            ...                    ...         ...                   ...
# 582            13                275.312          98                     0
# 583            18                251.818          96                     0
# 584            13                275.312          98                     0
# 585             6                251.818          96                     0
# 586            24                275.089          96                     0
#
#      Absenteeism_hours
# 0                   12
# 1                   17
# 2                    4
# 3                    3
# 4                   17
# ..                 ...
# 582                 32
# 583                  3
# 584                  8
# 585                 16
# 586                  8
#
# [587 rows x 9 columns]

# %%
df_grouped_ID_month.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587 entries, 0 to 586
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       587 non-null    int64
#  1   Month_absence            584 non-null    float64
#  2   Month_absence_name       584 non-null    object
#  3   Distance_Residence_Work  587 non-null    int64
#  4   Service_time             587 non-null    int64
#  5   Work_load_Average_day    587 non-null    float64
#  6   Hit_target               587 non-null    int64
#  7   Disciplinary_failure     587 non-null    int64
#  8   Absenteeism_hours        587 non-null    int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 41.4+ KB

# %%
df_grouped_ID_month['ID'].nunique()
# Out:
# 386

# %% [markdown]
# ### Cálculos score

# %% [markdown]
# Capacity

# %%
A_max = df_grouped_ID_month['Absenteeism_hours'].max()

df_grouped_ID_month['Capacity'] = 1 - df_grouped_ID_month['Absenteeism_hours'] / A_max

# Si quieres evitar valores negativos por algún outlier raro:
#df['Capacity'] = df['Capacity'].clip(lower=0)

# %% [markdown]
# Disciplinary failure, factor delta pequeño (0.10, 10% de penalización si hay disciplinary_failure)
# - Si Disciplinary_failure es 0 -> 1 (sin penalización)
# - Si es 1 -> 0.90 (10% de penalización)

# %%
delta = 0.10

df_grouped_ID_month['Disciplinary_component'] = 1 - delta * df_grouped_ID_month['Disciplinary_failure']

# %% [markdown]
# Hit_target normalizado por todos los meses, HitNorm estará entre 0 y 1

# %%
H_min = df_grouped_ID_month['Hit_target'].min()
H_max = df_grouped_ID_month['Hit_target'].max()

df_grouped_ID_month['HitNorm'] = (df_grouped_ID_month['Hit_target'] - H_min) / (H_max - H_min)

# %% [markdown]
# **Score final de rendimiento**
# Elegimos gamma para que Hit_target tenga más peso que disciplinary (0.30)

# %%
gamma = 0.30

df_grouped_ID_month['Score_rendimiento'] = (
    df_grouped_ID_month['Capacity'] *
    df_grouped_ID_month['Disciplinary_component'] *
    (1 + gamma * df_grouped_ID_month['HitNorm'])
)

# %% [markdown]
# Score final de rendimiento sin normalizar:
# - Descriptivo.
# - Crear categorías (bajo/medio/alto) con cuartiles.
# - Regresión logística (la variable es categórica, no el valor numérico).

# %% [markdown]
# *Normalizar* el score entre 0 y 1:
# - Gráficos más limpios (0–1).
# - Tablas comparativas donde quieres que el rango sea estándar.
# - Presentación visual (no afecta los análisis).

# %%
S_min = df_grouped_ID_month['Score_rendimiento'].min()
S_max = df_grouped_ID_month['Score_rendimiento'].max()

df_grouped_ID_month['Score_rendimiento_norm'] = (df_grouped_ID_month['Score_rendimiento'] - S_min) / (S_max - S_min)

# %% [markdown]
# Descriptivos agrupado ID mes

# %%
df_grouped_ID_month
# Out:
#       ID  Month_absence Month_absence_name  Distance_Residence_Work  \
# 0      1            1.0              Enero                       11
# 1      1            2.0            Febrero                       11
# 2      1            4.0              Abril                       11
# 3      1            5.0               Mayo                       11
# 4      1            6.0              Junio                       11
# ..   ...            ...                ...                      ...
# 582  382            1.0              Enero                       36
# 583  383            8.0             Agosto                       51
# 584  384            1.0              Enero                       36
# 585  385            8.0             Agosto                       27
# 586  386           12.0          Diciembre                       15
#
#      Service_time  Work_load_Average_day  Hit_target  Disciplinary_failure  \
# 0              14                252.079          97                     0
# 1              14                257.706          94                     0
# 2              14                265.017          88                     0
# 3              14                284.031          97                     0
# 4              14                236.629          97                     0
# ..            ...                    ...         ...                   ...
# 582            13                275.312          98                     0
# 583            18                251.818          96                     0
# 584            13                275.312          98                     0
# 585             6                251.818          96                     0
# 586            24                275.089          96                     0
#
#      Absenteeism_hours  Capacity  Disciplinary_component   HitNorm  \
# 0                   12    0.9700                     1.0  0.842105
# 1                   17    0.9575                     1.0  0.684211
# 2                    4    0.9900                     1.0  0.368421
# 3                    3    0.9925                     1.0  0.842105
# 4                   17    0.9575                     1.0  0.842105
# ..                 ...       ...                     ...       ...
# 582                 32    0.9200                     1.0  0.894737
# 583                  3    0.9925                     1.0  0.789474
# 584                  8    0.9800                     1.0  0.894737
# 585                 16    0.9600                     1.0  0.789474
# 586                  8    0.9800                     1.0  0.789474
#
#      Score_rendimiento  Score_rendimiento_norm
# 0             1.215053                0.936998
# 1             1.154039                0.889948
# 2             1.099421                0.847828
# 3             1.243237                0.958733
# 4             1.199395                0.924924
# ..                 ...                     ...
# 582           1.166947                0.899902
# 583           1.227566                0.946648
# 584           1.243053                0.958591
# 585           1.187368                0.915649
# 586           1.212105                0.934725
#
# [587 rows x 14 columns]

# %%
df_grouped_ID_month['ID'].nunique()
# Out:
# 386

# %%
df_grouped_ID_month.describe().T
# Out:
#                          count        mean         std      min         25%  \
# ID                       587.0  133.477002  123.068257    1.000   22.000000
# Month_absence            584.0    6.417808    3.514258    1.000    3.000000
# Distance_Residence_Work  587.0   28.850085   14.529176    5.000   16.000000
# Service_time             587.0   12.511073    4.508747    1.000    9.000000
# Work_load_Average_day    587.0  269.386283   38.372604  205.917  241.476000
# Hit_target               587.0   94.601363    3.754569   81.000   93.000000
# Disciplinary_failure     587.0    0.102215    0.303189    0.000    0.000000
# Absenteeism_hours        587.0   17.299830   42.635194    0.000    2.000000
# Capacity                 587.0    0.956750    0.106588    0.000    0.970000
# Disciplinary_component   587.0    0.989779    0.030319    0.900    1.000000
# HitNorm                  587.0    0.715861    0.197609    0.000    0.631579
# Score_rendimiento        587.0    1.150064    0.144666    0.000    1.127368
# Score_rendimiento_norm   587.0    0.886882    0.111560    0.000    0.869380
#
#                                 50%         75%        max
# ID                        93.000000  239.500000  386.00000
# Month_absence              6.000000    9.000000   12.00000
# Distance_Residence_Work   26.000000   42.000000   52.00000
# Service_time              13.000000   16.000000   29.00000
# Work_load_Average_day    264.249000  284.853000  378.88400
# Hit_target                95.000000   97.000000  100.00000
# Disciplinary_failure       0.000000    0.000000    1.00000
# Absenteeism_hours          8.000000   12.000000  400.00000
# Capacity                   0.980000    0.995000    1.00000
# Disciplinary_component     1.000000    1.000000    1.00000
# HitNorm                    0.736842    0.842105    1.00000
# Score_rendimiento          1.180553    1.230658    1.29675
# Score_rendimiento_norm     0.910393    0.949033    1.00000

# %% [markdown]
# Tu máximo de 1.29 es exactamente lo esperado:
# alguien con:
# - Capacity ≈ 1 (casi sin absentismo),
# - Sin disciplinary_failure,
# - HitNorm ≈ 1 (mejor mes),
# - obtendría un score cercano a 1.30.

# %% [markdown]
# ### Subset agrupado por ID con rendimiento para los análisis

# %%
df_rendimiento_grouped_ID = df_grouped_ID_month.groupby('ID').agg({
        'Distance_Residence_Work': 'first',
        'Service_time': 'first',
        'Work_load_Average_day': 'median',
        'Hit_target': 'first',
        'Disciplinary_failure': 'max',
        'Absenteeism_hours': 'sum',
        'Score_rendimiento': 'median'
    }).reset_index()

# %%
df_rendimiento_grouped_ID['Score_rendimiento'] = df_rendimiento_grouped_ID['Score_rendimiento'].round(2)

# %%
df_rendimiento_grouped_ID
# Out:
#       ID  Distance_Residence_Work  Service_time  Work_load_Average_day  \
# 0      1                       11            14               261.3615
# 1      2                       29            12               252.6895
# 2      3                       51            18               253.7110
# 3      4                       14            13               271.2190
# 4      5                       20            13               258.5890
# ..   ...                      ...           ...                    ...
# 381  382                       36            13               275.3120
# 382  383                       51            18               251.8180
# 383  384                       36            13               275.3120
# 384  385                       27             6               251.8180
# 385  386                       15            24               275.0890
#
#      Hit_target  Disciplinary_failure  Absenteeism_hours  Score_rendimiento
# 0            97                     1                121               1.18
# 1            92                     1                 25               1.11
# 2            97                     1                482               1.11
# 3            95                     0                  0               1.22
# 4            92                     1                104               1.14
# ..          ...                   ...                ...                ...
# 381          98                     0                 32               1.17
# 382          96                     0                  3               1.23
# 383          98                     0                  8               1.24
# 384          96                     0                 16               1.19
# 385          96                     0                  8               1.21
#
# [386 rows x 8 columns]

# %% [markdown]
# ## Análisis descriptivo

# %% [markdown]
# ### Distribución variable score_rendimiento (histograma y boxplot [outliers])

# %% [markdown]
# Subset agrupado ID y mes

# %%
distr_hist(df_grouped_ID_month,'Score_rendimiento',4)

# %%
distr_boxplot(df_grouped_ID_month,'Score_rendimiento')

# %% [markdown]
# Para saber el valor del outlier he mirado qué valores quedan fuera del cuartil Q1 y Q3.
# Los valores **outliers son menores a 0.74** (hay 41 registros), el mínimo es 0.

# %%
outliers_grouped_all = outliers_column(df_grouped_ID_month,'Score_rendimiento')
outliers_grouped_all.sort_values(
    by='Score_rendimiento',
    ascending=False
)
# Out:
#       ID  Month_absence Month_absence_name  Distance_Residence_Work  \
# 78    13            3.0              Marzo                       17
# 388  188           12.0          Diciembre                       13
# 498  298            3.0              Marzo                       25
# 25     3           12.0          Diciembre                       51
# 133   20            9.0         Septiembre                       50
# 439  239            1.0              Enero                       17
# 410  210            9.0         Septiembre                       36
# 243   43            3.0              Marzo                       36
# 92    14           11.0          Noviembre                       12
# 415  215            9.0         Septiembre                       14
# 414  214            9.0         Septiembre                       14
# 251   51            9.0         Septiembre                       14
# 98    15            5.0               Mayo                       31
# 22     3            9.0         Septiembre                       51
# 518  318            3.0              Marzo                       20
# 124   19            3.0              Marzo                       50
# 45     8            3.0              Marzo                       35
# 316  116            3.0              Marzo                       35
# 229   36            3.0              Marzo                       13
# 16     3            3.0              Marzo                       51
# 516  316            5.0               Mayo                       12
# 304  104            5.0               Mayo                       12
# 158   24            3.0              Marzo                       25
# 175   26           11.0          Noviembre                       26
# 134   20           10.0            Octubre                       50
# 64    11            3.0              Marzo                       36
# 553  353            1.0              Enero                       26
# 385  185            1.0              Enero                       26
# 505  305            1.0              Enero                       14
# 96    15            3.0              Marzo                       31
# 87    14            6.0              Junio                       12
# 77    13            1.0              Enero                       17
# 143   22            4.0              Abril                       26
# 236   36           12.0          Diciembre                       13
# 70    11            9.0         Septiembre                       36
# 219   34            6.0              Junio                       10
# 50     9            9.0         Septiembre                       14
# 181   28            1.0              Enero                       26
# 234   36           10.0            Octubre                       13
# 47     9            1.0              Enero                       14
# 86    14            5.0               Mayo                       12
#
#      Service_time  Work_load_Average_day  Hit_target  Disciplinary_failure  \
# 78             12                251.616          87                     1
# 388            18                377.550          94                     0
# 498            16                294.217          81                     0
# 25             18                253.957          95                     1
# 133            11                343.253          95                     0
# 439            12                264.604          93                     0
# 410            13                222.196          99                     0
# 243            13                294.217          81                     0
# 92             14                237.656          99                     0
# 415            16                222.196          99                     0
# 414            16                222.196          99                     0
# 251            16                222.196          99                     0
# 98             12                284.031          93                     1
# 22             18                222.196          95                     0
# 518            13                294.217          81                     1
# 124            12                294.217          81                     1
# 45             14                294.217          81                     1
# 316            14                294.217          81                     1
# 229            18                267.846          81                     1
# 16             18                277.986          81                     0
# 516            14                284.031          97                     0
# 304            14                284.031          97                     0
# 158            16                277.986          81                     0
# 175            13                237.656          99                     0
# 134            11                326.452          96                     0
# 64             13                267.846          81                     1
# 553             9                230.290          92                     0
# 385             9                230.290          92                     0
# 505            16                264.604          93                     0
# 96             12                294.217          81                     0
# 87             14                280.549          98                     0
# 77             12                264.604          93                     0
# 143             9                265.017          88                     0
# 236            18                377.550          94                     0
# 70             13                222.196          99                     0
# 219            10                261.306          97                     0
# 50             16                222.196          99                     0
# 181             9                230.290          92                     0
# 234            18                239.409          98                     0
# 47             16                264.604          93                     0
# 86             14                284.031          97                     0
#
#      Absenteeism_hours  Capacity  Disciplinary_component   HitNorm  \
# 78                   8    0.9800                     0.9  0.315789
# 388                 80    0.8000                     1.0  0.684211
# 498                 16    0.9600                     1.0  0.000000
# 25                  51    0.8725                     0.9  0.736842
# 133                 88    0.7800                     1.0  0.736842
# 439                 80    0.8000                     1.0  0.631579
# 410                104    0.7400                     1.0  0.947368
# 243                 24    0.9400                     1.0  0.000000
# 92                 111    0.7225                     1.0  0.947368
# 415                112    0.7200                     1.0  0.947368
# 414                112    0.7200                     1.0  0.947368
# 251                112    0.7200                     1.0  0.947368
# 98                  55    0.8625                     0.9  0.631579
# 22                  99    0.7525                     1.0  0.736842
# 518                  0    1.0000                     0.9  0.000000
# 124                  0    1.0000                     0.9  0.000000
# 45                   0    1.0000                     0.9  0.000000
# 316                  0    1.0000                     0.9  0.000000
# 229                  1    0.9975                     0.9  0.000000
# 16                  45    0.8875                     1.0  0.000000
# 516                120    0.7000                     1.0  0.842105
# 304                120    0.7000                     1.0  0.842105
# 158                 50    0.8750                     1.0  0.000000
# 175                128    0.6800                     1.0  0.947368
# 134                123    0.6925                     1.0  0.789474
# 64                  24    0.9400                     0.9  0.000000
# 553                112    0.7200                     1.0  0.578947
# 385                112    0.7200                     1.0  0.578947
# 505                120    0.7000                     1.0  0.631579
# 96                  88    0.7800                     1.0  0.000000
# 87                 160    0.6000                     1.0  0.894737
# 77                 160    0.6000                     1.0  0.631579
# 143                163    0.5925                     1.0  0.368421
# 236                198    0.5050                     1.0  0.684211
# 70                 232    0.4200                     1.0  0.947368
# 219                250    0.3750                     1.0  0.842105
# 50                 341    0.1475                     1.0  0.947368
# 181                348    0.1300                     1.0  0.578947
# 234                367    0.0825                     1.0  0.894737
# 47                 368    0.0800                     1.0  0.631579
# 86                 400    0.0000                     1.0  0.842105
#
#      Score_rendimiento  Score_rendimiento_norm
# 78            0.965558                0.744598
# 388           0.964211                0.743559
# 498           0.960000                0.740312
# 25            0.958832                0.739411
# 133           0.952421                0.734468
# 439           0.951579                0.733818
# 410           0.950316                0.732844
# 243           0.940000                0.724889
# 92            0.927842                0.715513
# 415           0.924632                0.713038
# 414           0.924632                0.713038
# 251           0.924632                0.713038
# 98            0.923329                0.712033
# 22            0.918842                0.708573
# 518           0.900000                0.694043
# 124           0.900000                0.694043
# 45            0.900000                0.694043
# 316           0.900000                0.694043
# 229           0.897750                0.692308
# 16            0.887500                0.684403
# 516           0.876842                0.676184
# 304           0.876842                0.676184
# 158           0.875000                0.674764
# 175           0.873263                0.673424
# 134           0.856513                0.660508
# 64            0.846000                0.652400
# 553           0.845053                0.651670
# 385           0.845053                0.651670
# 505           0.832632                0.642091
# 96            0.780000                0.601504
# 87            0.761053                0.586892
# 77            0.713684                0.550364
# 143           0.657987                0.507412
# 236           0.608658                0.469372
# 70            0.539368                0.415939
# 219           0.469737                0.362242
# 50            0.189421                0.146074
# 181           0.152579                0.117663
# 234           0.104645                0.080698
# 47            0.095158                0.073382
# 86            0.000000                0.000000

# %% [markdown]
# **Subset rendimiento (anterior) agrupado ID**

# %%
distr_hist(df_rendimiento_grouped_ID,'Score_rendimiento',4)

# %%
distr_boxplot(df_rendimiento_grouped_ID,'Score_rendimiento')

# %% [markdown]
# Para saber el valor del outlier he mirado qué valores quedan fuera del cuartil Q1 y Q3.
# Los valores **outliers son menores a 1.01** (hay 25 registros), el mínimo es 0,83.

# %%
outliers_grouped_ID = outliers_column(df_rendimiento_grouped_ID,'Score_rendimiento')
outliers_grouped_ID.sort_values(
    by='Score_rendimiento',
    ascending=False
)
# Out:
#       ID  Distance_Residence_Work  Service_time  Work_load_Average_day  \
# 185  186                       12            14                280.549
# 71    72                       13            18                294.217
# 92    93                       50            11                265.017
# 336  337                       27             6                265.017
# 324  325                       50            11                265.017
# 194  195                       20            13                265.017
# 177  178                       31            12                294.217
# 188  189                       31            12                294.217
# 370  371                       20            13                294.217
# 297  298                       25            16                294.217
# 187  188                       13            18                377.550
# 238  239                       17            12                264.604
# 209  210                       36            13                222.196
# 42    43                       36            13                294.217
# 213  214                       14            16                222.196
# 214  215                       14            16                222.196
# 50    51                       14            16                222.196
# 317  318                       20            13                294.217
# 115  116                       35            14                294.217
# 315  316                       12            14                284.031
# 103  104                       12            14                284.031
# 184  185                       26             9                230.290
# 352  353                       26             9                230.290
# 304  305                       14            16                264.604
#
#      Hit_target  Disciplinary_failure  Absenteeism_hours  Score_rendimiento
# 185          98                     0                 80               1.01
# 71           81                     0                  1               1.00
# 92           88                     1                  0               1.00
# 336          88                     1                  0               1.00
# 324          88                     1                  0               1.00
# 194          88                     1                  0               1.00
# 177          81                     0                  4               0.99
# 188          81                     0                  3               0.99
# 370          81                     0                  8               0.98
# 297          81                     0                 16               0.96
# 187          94                     0                 80               0.96
# 238          93                     0                 80               0.95
# 209          99                     0                104               0.95
# 42           81                     0                 24               0.94
# 213          99                     0                112               0.92
# 214          99                     0                112               0.92
# 50           99                     0                112               0.92
# 317          81                     1                  0               0.90
# 115          81                     1                  0               0.90
# 315          97                     0                120               0.88
# 103          97                     0                120               0.88
# 184          92                     0                112               0.85
# 352          92                     0                112               0.85
# 304          93                     0                120               0.83

# %% [markdown]
# ### Definir categorías score

# %% [markdown]
# Sobre los cuartiles? Además lo que queremos como objetivo es que la capacidad sea 1 como base, entonces los menores de uno (que además son los outliers) podrían ser los de bajo rendimiento.
# Tres grupos: bajo/medio/alto (cómo definir medio/alto). Alto mayor 0,75?

# %% [markdown]
# Terciles

# %%
df_rendimiento_grouped_ID['Score_clase'] = pd.qcut(
    df_rendimiento_grouped_ID['Score_rendimiento'],
    q=3,
    labels=['Q1 bajo', 'Q2 medio', 'Q3 alto']
)

# %%
df_rendimiento_grouped_ID['Score_clase'].value_counts()
# Out:
# Score_clase
# Q1 bajo     157
# Q2 medio    127
# Q3 alto     102
# Name: count, dtype: int64

# %%
df_rendimiento_grouped_ID.groupby('Score_clase')['Score_rendimiento'].describe().T
# Out:
# /var/folders/n6/b047z_cs09zgcrm2gkjd3hr00000gn/T/ipykernel_16641/3073890499.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_rendimiento_grouped_ID.groupby('Score_clase')['Score_rendimiento'].describe().T
# Score_clase     Q1 bajo    Q2 medio     Q3 alto
# count        157.000000  127.000000  102.000000
# mean           1.101656    1.204646    1.260392
# std            0.079895    0.018636    0.014066
# min            0.830000    1.180000    1.240000
# 25%            1.070000    1.190000    1.250000
# 50%            1.130000    1.210000    1.260000
# 75%            1.160000    1.220000    1.270000
# max            1.170000    1.230000    1.300000

# %% [markdown]
# Cuartiles

# %%
df_rendimiento_grouped_ID['Score_clase_4'] = pd.qcut(
    df_rendimiento_grouped_ID['Score_rendimiento'],
    q=4,
    labels=['Q1 bajo', 'Q2 medio-bajo', 'Q3 medio-alto','Q4 alto']
)

# %%
df_rendimiento_grouped_ID['Score_clase_4'].value_counts()
# Out:
# Score_clase_4
# Q1 bajo          112
# Q3 medio-alto    100
# Q2 medio-bajo     90
# Q4 alto           84
# Name: count, dtype: int64

# %%
df_rendimiento_grouped_ID.groupby('Score_clase_4')['Score_rendimiento'].describe().T
# Out:
# /var/folders/n6/b047z_cs09zgcrm2gkjd3hr00000gn/T/ipykernel_16641/1819523040.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_rendimiento_grouped_ID.groupby('Score_clase_4')['Score_rendimiento'].describe().T
# Score_clase_4     Q1 bajo  Q2 medio-bajo  Q3 medio-alto    Q4 alto
# count          112.000000      90.000000      100.00000  84.000000
# mean             1.075536       1.175111        1.22050   1.264762
# std              0.080994       0.009743        0.01424   0.011457
# min              0.830000       1.160000        1.20000   1.250000
# 25%              1.060000       1.170000        1.21000   1.260000
# 50%              1.090000       1.175000        1.22000   1.260000
# 75%              1.140000       1.180000        1.23000   1.270000
# max              1.150000       1.190000        1.24000   1.300000

# %% [markdown]
# ## Análisis descriptivo grupos

# %% [markdown]
# distribución, frecuencias, medias por grupo.
# El bajo rendimiento seguro y el alto puede.

# %% [markdown]
# ## Influencia

# %% [markdown]
# RLM / Spearman / MWU, KW

# %% [markdown]
# ## Spearman

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr

# %%
# 1. Definición de la variable objetivo y las variables de negocio
target_var = 'Score_rendimiento'
variables_negocio = [
    'Service_time',             # Antigüedad
    'Work_load_Average_day',    # Carga laboral diaria
    'Distance_Residence_Work'   # Distancia al trabajo
]

# %%
# 2. Cálculo de la correlación de Spearman
resultados = []
for var in variables_negocio:
    # Aseguramos que usamos el dataframe consolidado por ID
    df_temp = df_rendimiento_grouped_ID[[var, target_var]].dropna()
    rho, p_val = spearmanr(df_temp[var], df_temp[target_var])
    
    resultados.append({
        'Variable': var,
        'Rho': rho,
        'P-Value': p_val
    })

# 3. Creación del DataFrame de resultados para graficar
df_plot = pd.DataFrame(resultados).sort_values(by='Rho', ascending=False)

# %% [markdown]
# eje de 0.15 a 0.15 color dorado cambiar nombres a español

# %%
# Ordenado por impacto
df_etiquetas = df_plot.sort_values(by='Rho', ascending=False).copy()

# Formato bonito
df_etiquetas['Rho'] = df_etiquetas['Rho'].round(3)
df_etiquetas['P-Value'] = df_etiquetas['P-Value'].round(4)

print("\n📊 RESUMEN DE CORRELACIONES (SPEARMAN)\n")
print(df_etiquetas.to_string(index=False))
# Out:
# 📊 RESUMEN DE CORRELACIONES (SPEARMAN)
#
#                Variable    Rho  P-Value
# Distance_Residence_Work  0.055   0.2824
#            Service_time  0.029   0.5640
#   Work_load_Average_day -0.170   0.0008

# %%
plt.figure(figsize=(10, 6), facecolor='none')

# 🎨 colores
COLOR_POSITIVO = 'gold'
COLOR_NEGATIVO = 'darkorange'

#renombrar variables
nombres_es = {
    'Service_time': 'Antigüedad',
    'Work_load_Average_day': 'Carga laboral diaria',
    'Distance_Residence_Work': 'Distancia al trabajo',
}

df_plot = df_plot.copy()
df_plot['Variable'] = df_plot['Variable'].map(nombres_es)

colors = []

for var, rho in zip(df_plot['Variable'], df_plot['Rho']):
    
    if var in ['Distancia al trabajo', 'Antigüedad']:
        colors.append(COLOR_POSITIVO)
    
    else:
        colors.append(COLOR_NEGATIVO)
    

# gráfico
ax = sns.barplot(
    data=df_plot,
    x='Rho',
    y='Variable',
    palette=colors
)

ax.set_facecolor('none')

#eje limitado
plt.xlim(-0.20, 0.20)

plt.title('Influencia en el Score de Rendimiento (Spearman ρ)', fontsize=14)
plt.xlabel('Coeficiente de Correlación')
plt.ylabel('Variables de Negocio')

plt.axvline(0, color='black', linewidth=1)

plt.grid(axis='x', linestyle='--', alpha=0.4)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/n6/b047z_cs09zgcrm2gkjd3hr00000gn/T/ipykernel_16641/2737623566.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %% [markdown]
# 1. Variables con impacto significativo
#
# Distancia al trabajo es la única variable significativa (p = 0.034).
# Su efecto es positivo pero muy débil, indicando una relación marginal con el rendimiento.
# Aunque descriptivamente los empleados de alto rendimiento viven algo más cerca, el modelo ajustado muestra que el efecto real es pequeño.
#
# 2. Variables sin impacto significativo
#
# Antigüedad no influye en el rendimiento (p = 0.601).
# Carga laboral diaria tampoco es significativa (p = 0.640).
# Esto contradice parcialmente el análisis descriptivo, lo que indica que las relaciones simples no se mantienen al controlar otras variables.
#
# 3. Efectos del modelo
#
# La variabilidad entre empleados es muy baja (varianza ≈ 0.001).
# El rendimiento depende más de variaciones dentro del mismo empleado que de diferencias entre personas.
# El modelo se comporta casi como una regresión lineal simple.

# %% [markdown]
# RLM

# %%
formula = "Score_rendimiento ~ Service_time + Work_load_Average_day + Distance_Residence_Work"

modelo_rlm = smf.mixedlm(
    formula,
    df_grouped_ID_month,
    groups=df_grouped_ID_month["ID"]
)

resultado_rlm = modelo_rlm.fit()

print("RESUMEN DE LA REGRESIÓN LINEAL MIXTA")
print(resultado_rlm.summary())
# Out:
# RESUMEN DE LA REGRESIÓN LINEAL MIXTA
#               Mixed Linear Model Regression Results
# ==================================================================
# Model:             MixedLM  Dependent Variable:  Score_rendimiento
# No. Observations:  587      Method:              REML
# No. Groups:        386      Scale:               0.0192
# Min. group size:   1        Log-Likelihood:      285.6122
# Max. group size:   12       Converged:           Yes
# Mean group size:   1.5
# ------------------------------------------------------------------
#                         Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------
# Intercept                1.159    0.048 24.297 0.000  1.066  1.253
# Service_time            -0.001    0.001 -0.524 0.601 -0.003  0.002
# Work_load_Average_day   -0.000    0.000 -0.467 0.640 -0.000  0.000
# Distance_Residence_Work  0.001    0.000  2.122 0.034  0.000  0.002
# Group Var                0.001    0.004
# ==================================================================
# /opt/miniconda3/envs/mi_entorno/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
# Intervalos de confianza bien separados
conf_int = resultado_rlm.conf_int()
conf_int.columns = ['Lower_CI', 'Upper_CI']

summary_df = pd.DataFrame({
    'Coeficiente': resultado_rlm.params,
    'Error_Std': resultado_rlm.bse,
    'P-Value': resultado_rlm.pvalues
}).join(conf_int)

# Variables de interés (solo fijas)
variables_plot = [
    'Service_time',
    'Work_load_Average_day',
    'Distance_Residence_Work'
]

df_visual = summary_df.loc[variables_plot].reset_index().rename(
    columns={'index': 'Variable'}
)

# %%
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

colors = ['#2ecc71' if x > 0 else '#95a5a6' for x in df_visual['Coeficiente']]

# Barras (coeficientes)
plt.barh(
    df_visual['Variable'],
    df_visual['Coeficiente'],
    color=colors,
    alpha=0.85
)

# Intervalos de confianza
plt.errorbar(
    df_visual['Coeficiente'],
    df_visual['Variable'],
    xerr=[
        df_visual['Coeficiente'] - df_visual['Lower_CI'],
        df_visual['Upper_CI'] - df_visual['Coeficiente']
    ],
    fmt='none',
    ecolor='black',
    capsize=4
)

# Línea base
plt.axvline(0, color='black', linestyle='--', linewidth=1)

plt.title('Impacto de Variables en el Score de Rendimiento (RLM)', fontsize=14)
plt.xlabel('Coeficiente Beta')
plt.ylabel('Variables de Negocio')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Variable con impacto significativo
#
# Distancia al trabajo es la única variable significativa (p = 0.034).
# Tiene un efecto positivo pero muy pequeño sobre el rendimiento.
# Aun así, es el único factor con relación estadísticamente sólida en el modelo.
#
# 2. Variables sin impacto significativo
#
# Antigüedad no influye en el rendimiento (p = 0.601).
# Carga laboral diaria tampoco es significativa (p = 0.640).
# Esto indica que sus efectos no son lineales o no se mantienen al controlar por otras variables.
#
# 3. Efectos del modelo
#
# La variabilidad entre empleados es muy baja (varianza ≈ 0.001).
# El rendimiento es bastante consistente entre individuos.
# El modelo se comporta casi como una regresión lineal simple.

# %% [markdown]
# ## Perfiles

# %% [markdown]
# ### Regresión logística multinomial
# Qué variables (antigüedad, carga, distancia) aumentan/reducen la probabilidad de estar en bajo/medio/alto rendimiento.

# %% [markdown]
# ### Regresión lineal mixta?
# *Yo sí que la haría, mirar respuesta chatGPT*
# - Variable respuesta: Rendimiento (numérica, el score continuo).
# - Objetivo: entender cómo las variables predictoras (antigüedad, carga, distancia) se asocian con el rendimiento numérico.
#
# RLM es adecuado: rendimiento continuo, coeficientes interpretables.
# Pero no da perfiles clasificados, solo asociaciones numéricas.

# %% [markdown]
# **Perplexity**
# En tu caso:
# Dado que el mentor dice que la pregunta es "sencilla" y quieres identificar perfiles con menor rendimiento:
# **Mejor opción**: descriptivo + regresión logística multinomial.
# - Paso 1: cuartiles para categorizar bajo/medio/alto.
# - Paso 2: logística para identificar qué factores aumentan el riesgo de bajo rendimiento.
#
# El RLM sería más complejo y no te da perfiles clasificados, solo asociaciones con el score continuo.

# %% [markdown]
# Ahora mismo tenemos las dos técnicas, el RLM y la regresión logística multinomial.
#
# Dado que pide si tiene influencia y que creemos perfiles, sería mejor hacer las dos técnicas (RLM para influencia y multinomial para perfil)?
# No necesitas hacer ambas técnicas para una pregunta que es esencialmente sencilla. Con la regresión logística multinomial puedes responder tanto a la influencia como a los perfiles:
# 1. ¿Tiene influencia?
# La regresión logística multinomial ya te da la influencia:
# - Variable respuesta: Rendimiento_cat (bajo/medio/alto).
# - Predictores: antigüedad, carga laboral, distancia, disciplinary.
# - Resultado: odds ratios que indican:
#
# “Por cada año más de antigüedad, la probabilidad de estar en bajo rendimiento (vs alto) disminuye X%”.
#
# “Los empleados con disciplinary=1 tienen Y veces más probabilidad de estar en bajo rendimiento”.
#
# Esto ya responde a “¿qué variables tienen influencia en el rendimiento?”.
#
# 2. ¿Puedes identificar perfiles?
# Sí, la logística multinomial ya identifica perfiles:
# - Los odds ratios te dicen qué combinaciones de características te llevan a bajo/medio/alto.
#
# Puedes interpretar:
#
# - Perfil de bajo rendimiento: empleados con X características (ej.: alta distancia + disciplinary=1 + baja antigüedad).
# - Perfil de alto rendimiento: empleados con Y características.
# - Si quieres reglas explícitas, puedes añadir un árbol de decisión complementario, pero no necesitas RLM.
#
# **¿Por qué no RLM?**
# RLM con rendimiento continuo te da coeficientes numéricos, pero:
# - No categoriza empleados.
# - No da perfiles claros de “bajo/medio/alto”.
# - Es más difícil traducir a perfiles operativos para HR.
# - Ya elegiste categorizar rendimiento con cuartiles, así que la lógica natural es logística multinomial, no RLM.
#
# **Recomendación final**
# Para una pregunta sencilla (“¿tiene influencia? ¿puedes identificar perfiles?”):
#
# - Descriptivo: distribución, frecuencias, gráficos.
# - Regresión logística multinomial:
#     -Responde a “influencia” (odds ratios).
#     - Responde a “perfiles” (qué características te llevan a bajo/medio/alto).
#
# No necesitas RLM a menos que quieras:
#
# - Mostrar que también probaste con rendimiento continuo.
# - Comparar RLM vs. logística.
# Pero eso añade complejidad sin necesidad.

# %% [markdown]
# **ChatGPT**
# - Spearman → sí, como exploratorio
# - *Mann-Whitney / Kruskal-Wallis → opcional, solo si comparáis grupos claramente definidos*
# - RLM → sí, técnica principal para influencia
# - Multinomial → sí, técnica principal para perfiles
